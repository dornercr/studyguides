# %% [markdown]
# <a href="https://colab.research.google.com/github/dornercr/studyguides/blob/main/d_777_real_life_applications.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 1.1 Real Life Applications of Data Structures – Study Guide
#
# ## 🎯 Main Idea
# **Data structures help software engineers solve real-world problems by organizing and managing data efficiently.**
#
# ---
#
# ## 🏢 Why It Matters (Real-Life Use)
# - Businesses use data structures to **store, search, sort**, and **process** large amounts of data.
# - Picking the **right data structure** saves **time, memory, and money**.
#
# ---
#
# ## ⚙️ What You Learn in This Course
#
# ### Common Data Structures
# - Arrays
# - Linked Lists
# - Stacks
# - Queues
# - Trees
# - Graphs
# - Hash Tables
#
# ### Algorithms
# - Ways to **process data** (e.g., searching, sorting)
# - Learn about **time complexity** and **space complexity**
#
# ### Python Implementation
# - Write and test your own data structures in **Python**
# - Use real Python libraries like:
#   - `collections`
#   - `heapq`
#   - `networkx`
#
# ### AI Intro
# - Learn how **AI algorithms** use data structures to **improve predictions and decisions**
#
# ### Integration
# - Mix data from different sources: **files**, **databases**, **APIs**
# - Understand challenges when **combining data**
#
# ---
#
# ## 🧠 Course Competencies (What You Should Be Able to Do)
#
# | Competency  | What It Means (Simplified)                                     |
# |-------------|----------------------------------------------------------------|
# | 4130.2.1    | Pick the best data structure for a business problem.           |
# | 4130.2.2    | Decide which algorithm is faster or uses less space.           |
# | 4130.2.3    | Code the right data structure in Python.                       |
# | 4130.2.4    | Handle problems when mixing different data.                    |
# | 4130.2.5    | Find Python tools that help you use algorithms easily.         |
#
# ---
#
# ## 🧩 Mnemonic: **APE AI**
# - **A**rrays and **A**lgorithms
# - **P**ython structures
# - **E**fficiency (time & space)
# - **A**I libraries
# - **I**ntegration of data

# %% [markdown]
# # 📘 1.2 Learning Resources – Study Guide
#
# ## 🔧 Main Tool: Git
# **Git** is a **version control system**.
#
# It helps you:
# - Track code changes
# - Collaborate with teammates
# - Revert to earlier versions if something breaks
#
# ---
#
# ## 🧠 Why Git Is Important
# You can:
# - **Track every change** made to the code
# - **Work together** without overwriting each other's changes
# - **Fix mistakes** by reverting to earlier versions
# - **Test new ideas** using branches before merging into the main project
#
# ---
#
# ## 🔗 Branching and Merging
# - **Branch**: A copy of the code where you can test something new safely
# - **Merge**: Combine the changes from a branch into the main project
#
# ---
#
# ## 🧰 Tools Used
# - You’ll use **GitLab** (not GitHub) in this course
# - You’ll watch **Git Essential Training (01:23:00)** on LinkedIn Learning to learn how Git works
#
# ---
#
# ## 🧠 Quick Facts to Memorize
#
# | Term             | Meaning                                      |
# |------------------|----------------------------------------------|
# | Git              | Tracks code changes over time                |
# | Version Control  | Keeps a history of all code edits            |
# | Branch           | A safe place to try new code ideas           |
# | Merge            | Bring branch code into the main project      |
# | GitLab           | The platform you’ll use in this course       |
#
# ---
#
# ## ✏️ Mnemonic: **GITBM**
# - **G**it
# - **I**solate changes with **Branches**
# - **T**rack code history
# - **B**ackup and revert
# - **M**erge when ready

# %% [markdown]
# # 🧭 1.3 Course Organization and Navigation – Study Guide
#
# ## 🧱 How the Course Works
# - Each lesson has **headings** to show what’s important
# - You’ll move through **sections, lessons, and pages** using **links**
# - Always return to the **main course page** after finishing a part
#
# ---
#
# ## 🔁 How to Progress
# - Don’t just scroll through everything
# - Only complete what the **course tells you to do** — some parts may not be required
# - If a video or document opens in a **new tab**, **close it** and return to the course when done
#
# ---
#
# ## 🧠 Lesson Materials Might Include:
# - 🔗 **Links** to videos or readings
# - 🖼️ **Pictures** or sample files
# - 🧪 **Exercises and projects** to practice
#
# ---
#
# ## ✅ Knowledge Checks
# - Not graded quizzes
# - Help reinforce key concepts and ideas from the lesson
#
# ---
#
# ## 📌 Tips to Remember
#
# | Feature          | What It Means                                 |
# |------------------|------------------------------------------------|
# | **Links**        | Take you to lesson parts or resources          |
# | **Headings**     | Show the main idea of each section             |
# | **Assignments**  | Follow instructions, then go back to course    |
# | **Knowledge Checks** | Help practice, not for a grade            |
#
# ---
#
# ## 🧠 Mnemonic: **L-H-A-K**
# - **L**inks guide you
# - **H**eadings lead each part
# - **A**ssignments → return to course
# - **K**nowledge checks = practice

# %% [markdown]
# # 🧠 2.2 Algorithms Overview – Explained Simply
#
# ## 💡 What Is an Algorithm?
# An **algorithm** is a **step-by-step set of instructions** a computer follows to solve a problem or perform a task.
#
# > Think of it like a recipe: Just like a recipe tells you what to do in what order to make a dish, an algorithm tells the computer what to do and when.
#
# ---
#
# ## 📋 Characteristics of a Good Algorithm
#
# | Characteristic        | What It Means (Simple Definition)                                |
# |------------------------|------------------------------------------------------------------|
# | **Unambiguous**        | Every step must be clear and have only one meaning               |
# | **Finite**             | The algorithm must end eventually (not go on forever)            |
# | **Well-defined input** | You know exactly what data you’re starting with                 |
# | **Well-defined output**| You know exactly what result you’re expecting at the end         |
# | **Effective**          | Each step must be doable with simple instructions                |
# | **Feasible**           | It should be possible to actually run the steps on a computer    |
# | **Language-independent** | The steps work no matter what programming language is used    |
#
# ---
#
# ## 📊 What Are Data Flow Diagrams?
#
# A **Data Flow Diagram (DFD)** is a drawing that shows how **data moves through a system**.
#
# - It uses **symbols** to show:
#   - Where the data **starts**
#   - How the data **moves**
#   - Where the data **ends**
#
# > Businesses use DFDs to visualize their processes and find ways to make them better.
#
# ---
#
# ## 🧪 Example
#
# **Pizza Shop DFD**:
# - Customer → Cashier → Kitchen → Delivery
#
# This shows the **flow of data (orders)** through the pizza shop system.

# %% [markdown]
# # 🧠 2.3 Introduction to Algorithms – Study Guide
#
# ## 💡 What Is an Algorithm?
# An algorithm is a **sequence of steps** a computer follows to solve a computational problem.
#
# Algorithms can be written in:
# - English
# - Pseudocode
# - Programming languages
# - Flowcharts or diagrams
#
# ---
#
# ## 🧪 Computational Problem
#
# A computational problem always includes:
#
# | Component | Example                                |
# |----------|-----------------------------------------|
# | Input    | Array: `[13, 7, 45, -3, 92, 17]`        |
# | Question | "What is the largest number?"          |
# | Output   | `92`                                   |
#
# 📌 Algorithms are used to **answer questions about input data**.
#
# ---
#
# ## 🧰 Example Algorithm: FindMax()
#
# FindMax(inputArray):
#     max = inputArray[0]
#     for i from 1 to inputArray.size:
#         if inputArray[i] > max:
#             max = inputArray[i]
#     return max
#
# ✅ This finds the **maximum value** in an array.
#
# ---
#
# ## 🗂️ Real-World Applications and Matching Algorithms
#
# | Domain         | Problem (Input + Question)                      | Algorithm Used             |
# |----------------|--------------------------------------------------|----------------------------|
# | DNA Analysis   | Longest matching sequence in 2 DNA strings       | Longest Common Substring   |
# | Search Engines | Product ID lookup in sorted inventory            | Binary Search              |
# | Navigation     | Shortest walking route from point A to B         | Dijkstra’s Shortest Path   |
#
# 🧠 Tip: Real-world problems are usually combinations of **smaller subproblems**, solved with known efficient algorithms.
#
# ---
#
# ## ❗ NP-Complete Problems
#
# Some problems have no known efficient algorithm. These are **NP-complete** problems:
#
# - No known **polynomial-time** solution
# - Not proven impossible either
# - If **one** NP-complete problem is solved efficiently, **all** can be
#
# ---
#
# ## 🧪 Example: Clique Problem (NP-Complete)
#
# | Component | Example                                                                 |
# |-----------|-------------------------------------------------------------------------|
# | Input     | Graph of people (nodes = people, edges = friendships) + K (group size) |
# | Question  | Do K people all know each other?                                       |
# | Output    | `True` or `False` (Boolean)
#
# 🔍 K = 3 → Yes
# 🔍 K = 4 → No
#
# This is the **Clique Decision Problem** — it’s **NP-complete**.
#
# ---
#
# ## ✅ Quiz Recap (2.3 Participation Activities)
#
# | Question                                                             | Answer     |
# |----------------------------------------------------------------------|------------|
# | A polynomial-time algorithm is efficient.                           | ✅ True    |
# | Efficient algorithms exist for all computational problems.          | ❌ False   |
# | An efficient algorithm for NP-complete problems might exist.        | ✅ True    |
# | Input for counting word frequency = array of all words + search word| ✅ True    |
# | Output = how many times the word appears                            | ✅ True    |
# | Algorithms must be written in a programming language                | ❌ False   |
#
# ---
#
# ## 🧠 Summary Mnemonic: IQO-DNA-Clique
# - **I**nput
# - **Q**uestion
# - **O**utput
# - **DNA** → Longest Common Substring
# - **Navigation** → Dijkstra
# - **Amazon** → Binary Search
# - **Clique** → NP-Complete

# %% [markdown]
# # 🧠 2.4 Relation Between Data Structures and Algorithms – Study Guide
#
# ## 📘 What You Need to Know
# Data Structures = How data is organized and stored
# Algorithms = How data is processed or manipulated
#
# 🔑 The structure affects how you write the algorithm.
#
# Example:
# - Inserting into an **array** ≠ inserting into a **linked list**
# - Each structure has its own method for append, insert, search, etc.
#
# ---
#
# ## 🔁 Algorithms for Data Structures
#
# ### ✏️ ArrayAppend(array, newItem)
# ArrayAppend(array, newItem):
#
#     // Step 1: Get current size
#     size = array⇢length
#
#     // Step 2: Resize array to fit new item
#     Increase array size by 1
#
#     // Step 3: Add new item to the end
#     array[size] = newItem
#
#
# - Must grow if full
# - Accessed by index
# - Simple but may use more memory
#
# ---
#
# ### ✏️ ListAppend(list, newNode)
# ListAppend(list, newNode):
#
#     // Step 1: Check if the list is empty
#     if list⇢head == null:
#         list⇢head = newNode
#         list⇢tail = newNode
#
#     // Step 2: Otherwise, append to the end
#     else:
#         list⇢tail⇢next = newNode
#         list⇢tail = newNode
#
#     // Step 3: Increase list length
#     list⇢length++
#
# - Changes pointers
# - No resizing needed
# - More flexible
#
# ---
#
# ## ✅ Participation Activity Summary
#
# | Task                  | Same Code? | Why                                    |
# |-----------------------|------------|----------------------------------------|
# | Append an item        | ❌ No      | Arrays use indices, lists use pointers |
# | Return the first item | ❌ No      | array[0] vs list⇢head                  |
# | Return the size       | ✅ Yes     | Both use ⇢length                       |
#
# ### ✅ Code to Get Length
# Pseudocode:
# GetCurrentSize(values):
#     return values⇢length
#
# ---
#
# ## 🏆 Top Five Salespersons Algorithm
#
# ### Goal:
# Keep track of top 5 salespeople using an array.
#
# ### 📋 Steps (Pseudocode):
# DisplayTopFiveSalespersons(allSalespersons):
#
#     // Step 1: Initialize topSales array
#     topSales = array of 5 items
#     for i from 0 to 4:
#         topSales[i]⇢name = ""
#         topSales[i]⇢salesTotal = -1
#
#     // Step 2: Loop through all salespeople
#     for each salesPerson in allSalespersons:
#         if salesPerson⇢salesTotal > topSales[4]⇢salesTotal:
#             topSales[4]⇢name = salesPerson⇢name
#             topSales[4]⇢salesTotal = salesPerson⇢salesTotal
#             SortDescending(topSales)
#
#     // Step 3: Display results
#     for i from 0 to 4:
#         Display topSales[i]
#
# ---
#
# ## 🧠 Quiz Review (Top 5 Algorithm)
#
# | Question                           | Answer     | Why                                                   |
# |------------------------------------|------------|--------------------------------------------------------|
# | Is topSales⇢length = 5?           | ✅ True    | Fixed array of 5                                       |
# | Is allSalespersons⇢length = 5?    | ❌ False   | Could be any length                                    |
# | Switch to top 10?                 | 🛠 Change  | Update array size and loop range                       |
# | Only 3 salespeople?               | ✅ True    | Remaining entries stay blank but still display         |
#
# ---
#
# ## 🧠 Algorithms Use Data Structures To:
# - Store temporary data
# - Sort values
# - Hold filtered results
# - Track comparisons
#
# **Example**: Top 5 sales algorithm uses an array to maintain order.
#
# ---
#
# ## 🧩 Full Diagram: Relation Summary
#
# Data Structure ↔ Algorithm ↔ Real-World Task
#         ↓               ↓
#       Array       →     Sort, Append
#   Linked List     →     Insert, Delete
#       Graph       →     Pathfinding (Dijkstra)
#    Hash Table     →     Fast lookup
#
# ---
#
# ## 🔍 Key Takeaways
# - **Different structures → different algorithms**
# - Same task may require **different code**
# - Algorithms depend on structure behavior (access time, size, etc.)
# - Some actions (e.g., length) are universal
#
# ---
#
# ## 🧠 Mnemonic: S.T.O.R.E.
# - **S**tructure
# - **T**ells you
# - **O**perations to
# - **R**un
# - **E**ffectively
