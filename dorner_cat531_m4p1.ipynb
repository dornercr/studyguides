# %% [markdown]
# <a href="https://colab.research.google.com/github/dornercr/studyguides/blob/main/dorner_cat531_m4p1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
score = 0

answer = input("1. What does ML stand for? ")
if answer.lower() == "machine learning":
    score += 1

answer = input("2. What library is commonly used for ML in Python? ")
if answer.lower() in ["scikit-learn", "sklearn"]:
    score += 1

answer = input("3. What type of learning uses labeled data? ")
if answer.lower() == "supervised learning":
    score += 1

print("Your score:", score, "/3")
# Out:
# 1. What does ML stand for? machine learning
# 2. What library is commonly used for ML in Python? sklearn
# 3. What type of learning uses labeled data? supervised learning
# Your score: 3 /3
