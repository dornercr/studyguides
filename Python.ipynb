# %% [markdown]
# <a href="https://colab.research.google.com/github/dornercr/studyguides/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 Section 1: Language Fundamentals (with YouTube links)
#
# ## 1.1 Source File & Encoding
#
# - A Python source file is a `.py` text file.
# - Default encoding: UTF‑8.
# - Custom encoding must be declared:
#
# ```python
# # -*- coding: iso-8859-1 -*-
# ```
#
# **Video:** Character Encoding in Python
# https://www.youtube.com/watch?v=CxeP1dQi9rg
#
# ---
#
# ## 1.2 Lexical Structure & Tokenization
#
# - Token = smallest unit of code.
# - Categories: keyword, identifier, literal, operator, delimiter.
# - Tokens are compiled into an abstract syntax tree (AST).
#
# **Video:** Lexical Structure of Python
# https://www.youtube.com/watch?v=m_8X6moMDGc
#
# ---
#
# ## 1.3 Identifiers (Names)
#
# - Start with a letter or `_`, followed by letters/digits/underscores.
# - Case-sensitive. Cannot use keywords.
# - Special forms: `_name`, `__name`, `__name__`.
#
# **Video:** What Is An Identifier In Python
# https://www.youtube.com/watch?v=Sf2EzJogbcc
#
# ---
#
# ## 1.4 Literals (Fixed Values)
#
# - Numeric: int, float, complex.
# - String types: str, bytes, bytearray.
# - Special: `True`, `False`, `None`, `Ellipsis`, `NotImplemented`.
#
# **Video:** Python Literals Explained
# https://www.youtube.com/watch?v=8Pvv9W9ix5Y
#
# ---
#
# ## 1.5 Operators & Special Methods
#
# - Operators map to methods: `+` → `__add__`, `==` → `__eq__`, etc.
# - Categories: arithmetic, bitwise, comparison, logical, identity, membership, assignment.
#
# **Video:** Python Operators for Beginners
# https://www.youtube.com/watch?v=7BxUaeROVXI
#
# ---
#
# ## 1.6 Indentation & Block Structure
#
# - Indentation (not braces) defines block scope.
# - Consistency required. PEP 8 recommends 4 spaces.
#
# **Video:** Python Indentation Tutorial
# https://www.youtube.com/watch?v=l4CdyZPDYE4
#
# ---
#
# ## 1.7 Line Structure
#
# - Physical line = ends with newline.
# - Logical line = may span multiple lines via `\\` or grouping.
#
# **Video:** (covered within full tutorials; no standalone link)
#
# ---
#
# ## 1.8 Comments & Docstrings
#
# - `#` starts a comment.
# - Docstring = first string literal in a class/module/function.
#
# **Video:** (covered within full tutorials; no standalone link)
#
# ---
#
# ## 1.9 Truth Value Testing
#
# - Falsy: `None`, `False`, 0, `''`, `[]`, `{}`.
# - Custom: `__bool__()` or `__len__()`.
#
# **Video:** (covered within full tutorials; no standalone link)
#
# ---
#
# ## 1.10 Execution Context
#
# - `__name__ == "__main__"` checks if script was executed directly.
# - `__file__` and `sys.argv` are context variables.
#
# **Video:** (covered within full tutorials; no standalone link)
#
# ---
#
# ## 1.11 Shebang
#
# - `#!/usr/bin/env python3` for Unix interpreter line.
# - Must be at line 1, column 0.
#
# **Video:** (covered in Python CLI setup tutorials)

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

# Section content
subsections = [
    ("1.1 Source File & Encoding", """
<pre><code class="language-python">
# -*- coding: iso-8859-1 -*-
</code></pre>

- A Python source file is a `.py` text file
- Default encoding: UTF‑8
- Custom encoding must be declared

**Video:** Character Encoding in Python
https://www.youtube.com/watch?v=CxeP1dQi9rg
"""),

    ("1.2 Lexical Structure & Tokenization", """
- Token = smallest unit of code
- Categories: keyword, identifier, literal, operator, delimiter
- Tokens are compiled into an abstract syntax tree (AST)

**Video:** Lexical Structure of Python
https://www.youtube.com/watch?v=m_8X6moMDGc
"""),

    ("1.3 Identifiers (Names)", """
- Start with a letter or `_`, followed by letters/digits/underscores
- Case-sensitive. Cannot use keywords
- Special forms: `_name`, `__name`, `__name__`

**Video:** What Is An Identifier In Python
https://www.youtube.com/watch?v=Sf2EzJogbcc
"""),

    ("1.4 Literals (Fixed Values)", """
- Numeric: int, float, complex
- String: str, bytes, bytearray
- Special: `True`, `False`, `None`, `Ellipsis`, `NotImplemented`

**Video:** Python Literals Explained
https://www.youtube.com/watch?v=8Pvv9W9ix5Y
"""),

    ("1.5 Operators & Special Methods", """
- Operators map to methods: `+` → `__add__`, `==` → `__eq__`
- Categories: arithmetic, bitwise, comparison, logical, identity, membership, assignment

**Video:** Python Operators for Beginners
https://www.youtube.com/watch?v=7BxUaeROVXI
""")
]

# UI setup
index = 0
output = widgets.Output()

def show_next(_):
    global index
    output.clear_output()
    with output:
        if index < len(subsections):
            title, content = subsections[index]
            display(Markdown(f"### 🧠 Now Studying: {title}\n\n{content}"))
            index += 1
        else:
            display(Markdown("🎓 **You’ve completed Section 1! Take a break, twin.**"))

next_button = widgets.Button(description="Next ▶️")
next_button.on_click(show_next)

display(next_button, output)

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

# (question, answer, PEMDAS-style mnemonic)
flashcards = [
    (
        "What is the default source encoding in Python, and how can it be overridden?",
        "`UTF-8` is the default encoding for `.py` files.\nTo override, declare a coding header in the first or second line:\n<pre><code class='language-python'># -*- coding: iso-8859-1 -*-</code></pre>\nIf no header is present and encoding is not UTF-8, Python raises a `SyntaxError`.",
        "**Mnemonic:** Ugly Trolls Fart 8 times → UTF-8"
    ),
    (
        "What are Python's token types, and what happens after tokenization?",
        "Python tokenizes code into: `keyword`, `identifier`, `literal`, `operator`, `delimiter`.\nTokens are passed to the parser and compiled into an abstract syntax tree (AST).\nWhitespace and comments are ignored at the tokenizer level.",
        "**Mnemonic:** Killer Iguanas Love Open Donuts → Keyword, Identifier, Literal, Operator, Delimiter"
    ),
    (
        "What are the rules for valid identifiers in Python, and what are common pitfalls?",
        "Identifiers must start with a letter or underscore, followed by letters, digits, or underscores.\nThey are case-sensitive and cannot be keywords.\nLeading underscores (`_var`) suggest internal use; double underscore (`__var`) triggers name mangling.\nReserved dunder names like `__init__`, `__name__` have language-defined behavior.\nUnicode letters (e.g., `变量`) are allowed but discouraged in production.",
        "**Mnemonic:** Some Letters Define Ugly Code → Start, Letter, Digits, Underscore, Case"
    ),
    (
        "What kinds of literals exist in Python, and what do special literals do?",
        "Python supports:\n- Numeric literals: `int`, `float`, `complex`\n- Text: `str`, `bytes`, `bytearray`\n- Constants: `True`, `False`, `None`, `Ellipsis` (`...`), `NotImplemented`\n`Ellipsis` is often used in slicing and placeholder logic. `NotImplemented` is returned by binary operators if not supported.",
        "**Mnemonic:** Icy Frogs Can Swim Backward Before They Fly Near Evil Nights"
    ),
    (
        "How are operators implemented in Python and what are key edge behaviors?",
        "Operators are syntactic sugar for special methods, e.g. `+` → `__add__`, `==` → `__eq__`.\nBinary ops fall back to `__radd__`, etc., if left-hand op fails or returns `NotImplemented`.\nAssignment (`=`) is not overloadable.\nIn-place ops like `+=` use `__iadd__` if available.\nOperator categories: arithmetic, bitwise, comparison, logical, identity, membership, assignment.",
        "**Mnemonic:** All Big Cats Love Ice-cold Minty Apples"
    ),
    (
        "How does Python define block structure, and what errors can occur?",
        "Python uses **indentation** (not braces) to define blocks.\nIndentation must be consistent (PEP 8 recommends 4 spaces).\nMixing tabs and spaces leads to a `TabError`.\nBlocks are required after `if`, `for`, `def`, `class`, etc.",
        "**Mnemonic:** Indents Beat Braces Permanently"
    ),
    (
        "How does Python handle physical and logical lines?",
        "A physical line ends in a newline (`\\n`).\nA logical line may span multiple physical lines using `\\` or implied continuation inside `()`, `[]`, `{}`.\nImproper continuation can cause `SyntaxError` or misaligned statements.",
        "**Mnemonic:** Please Let Code Breathe → Physical, Logical, Continuation, Brackets"
    ),
    (
        "What are Python's rules for comments and docstrings?",
        "`#` starts a comment, which runs to the end of the line.\nDocstrings are triple-quoted strings placed at the top of functions, classes, or modules.\nOnly the first string literal in those scopes is treated as a docstring (`__doc__`).",
        "**Mnemonic:** Comment Sharply, Document First"
    ),
    (
        "Which values are considered false in Python, and how is truth tested?",
        "`False`, `None`, numeric zero (`0`, `0.0`), empty sequences/collections (`''`, `[]`, `{}`), and custom objects with `__bool__()` returning `False` or `__len__()` returning 0.\nIf both `__bool__()` and `__len__()` exist, `__bool__()` is used.",
        "**Mnemonic:** No Funny Zero Stuff Counts"
    ),
    (
        "What is the purpose of `__name__ == '__main__'` and what are context variables?",
        "When a script is run directly, `__name__ == '__main__'` is `True`.\nWhen imported, it's set to the module name.\n`__file__` gives the path to the script; `sys.argv` holds CLI arguments.",
        "**Mnemonic:** Many Files Are Real Scripts"
    ),
    (
        "What is a shebang and how is it used in Python?",
        "The shebang (`#!`) must be at the very first line (col 0) of the script.\nIt specifies which interpreter to use, e.g. `#!/usr/bin/env python3`.\nUnix uses it to launch the script; Windows ignores it.",
        "**Mnemonic:** Sharp Has Executable Bash Assigned Next Globally"
    )
]
index = 0
output = widgets.Output()

show_button = widgets.Button(description="Show Answer 👁️")
next_button = widgets.Button(description="Next ▶️")

def show_answer(_):
    with output:
        clear_output(wait=True)
        question, answer, mnemonic = flashcards[index]
        display(Markdown(f"**Q:** {question}  \n\n---\n\n**A:** {answer}  \n\n{mnemonic}"))

def next_card(_):
    global index
    index += 1
    output.clear_output()
    if index < len(flashcards):
        with output:
            display(Markdown(f"**Q:** {flashcards[index][0]}"))
    else:
        with output:
            display(Markdown("🧠 **Done with Section 1, twin. Locked in.**"))

show_button.on_click(show_answer)
next_button.on_click(next_card)

with output:
    display(Markdown(f"**Q:** {flashcards[index][0]}"))

display(widgets.HBox([show_button, next_button]), output)
