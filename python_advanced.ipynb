# %% [markdown]
# <a href="https://colab.research.google.com/github/dornercr/studyguides/blob/main/python_advanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 Section 1: Python Fundamentals — Syntax, Source Structure, and Variables
#
# ---
#
# ## 🔹 1. Python Source Files
#
# ### ✅ Definition
# Python source code is stored in `.py` files and interpreted by the Python runtime. Each file is a module.
#
# ### ✅ Default Encoding
# Python 3 source files are `UTF-8` by default. This allows Unicode characters (like emojis or foreign text).
#
# ### ✅ Custom Encoding (rare)
# To use a different encoding (e.g., ISO-8859-1), declare it on the first or second line:
#
# ```python
# # -*- coding: iso-8859-1 -*-
# ```
#
# If a non-UTF-8 character is used without this declaration, you'll get a `SyntaxError`.
#
# ---
#
# ## 🔹 2. Indentation and Block Structure
#
# ### ✅ Definition
# Python uses **whitespace indentation** to define code blocks instead of braces `{}`. This enforces readability.
#
# ### ✅ Rules
# - You must be consistent: use either **4 spaces** or **tabs**, not both.
# - Indentation is required after:
#   - `if`, `for`, `while`, `def`, `class`, etc.
#
# ### ✅ Example
#
# ```python
# if True:
#     print("Indented block")  # 4 spaces
#
# print("Outside block")
# ```
#
# Bad example (`❌ SyntaxError`):
#
# ```python
# if True:
# print("This is bad")  # Not indented
# ```
#
# ---
#
# ## 🔹 3. Keywords and Identifiers
#
# ### ✅ Keywords
# Reserved words in Python that cannot be used as variable names.
#
# ```python
# True, False, None, def, return, if, elif, else,
# while, for, in, is, not, and, or
# ```
#
# Using a keyword as a variable name raises a `SyntaxError`.
#
# ### ✅ Identifiers
#
# - Must start with a letter (a–z, A–Z) or underscore `_`
# - Followed by letters, digits, or underscores
# - Cannot use symbols like `$`, `@`, `!`
# - Case-sensitive: `Name` ≠ `name`
#
# ---
#
# ## 🔹 4. Variable Assignment
#
# ### ✅ Syntax
#
# ```python
# x = 5
# name = "Alice"
# ```
#
# Python assigns variables using **reference binding** — the name points to an object in memory.
#
# ### ✅ Multiple Assignment
#
# ```python
# a, b = 1, 2
# x = y = z = 0
# ```
#
# ### ✅ Swapping
#
# ```python
# a, b = b, a
# ```
#
# ---
#
# ## 🔹 5. `=` vs `==`
#
# | Operator | Meaning       | Example     |
# |----------|---------------|-------------|
# | `=`      | Assignment     | `x = 10`    |
# | `==`     | Equality test  | `x == 10`   |
#
# ```python
# x = 5
# print(x == 5)  # True
# ```
#
# ---
#
# ## 🔹 6. Comments
#
# - **Single-line:** use `#`
# - **Multiline:** use triple-quotes (not technically comments, but ignored by interpreter unless used as docstrings)
#
# ```python
# # This is a comment
#
# """
# This is a block of documentation,
# but still executes unless ignored by interpreter.
# """
# ```
#
# ---
#
# ## ✅ Summary Table
#
# | Concept        | Keyword       | Example                         |
# |----------------|---------------|---------------------------------|
# | Source file    | `.py` file     | `main.py`                       |
# | Encoding       | UTF-8 default | `# -*- coding: utf-8 -*-`       |
# | Indentation    | 4 spaces      | After `if`, `def`, etc.         |
# | Identifier     | a_z, 0_9, `_` | `name_1`, `_temp`               |
# | Assignment     | `=`           | `x = 10`                        |
# | Comparison     | `==`          | `x == 10`                       |
# | Comments       | `#`           | `# this is a comment`           |

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

# (question, answer, PEMDAS-style mnemonic)
flashcards = [
# 1.1 Source Encoding
("What is the default encoding of Python source files?",
 "`UTF-8` is the default encoding for `.py` files.",
 "**Mnemonic:** Ugly Trolls Fart 8 times"),

("How do you override the source encoding?",
 "Declare a coding header on the first or second line:\n```python\n# -*- coding: iso-8859-1 -*-\n```",
 "**Mnemonic:** She’s First or Second"),

("What happens if encoding is wrong and undeclared?",
 "If the file contains non-UTF-8 bytes without a coding declaration, Python raises `SyntaxError`.",
 "**Mnemonic:** Syntax Errors Follow Undeclared Bytes"),

# 1.2 Indentation and Blocks
("What defines block structure in Python?",
 "Python uses indentation (not braces) to define code blocks.",
 "**Mnemonic:** Indents Build Blocks"),

("What is the recommended indentation rule in PEP 8?",
 "Use 4 spaces per indentation level.",
 "**Mnemonic:** Proper Eight Paces"),

("What happens when tabs and spaces are mixed?",
 "Python raises a `TabError` at runtime.",
 "**Mnemonic:** Tabs And Braces Explode"),

# 1.3 Keywords and Identifiers
("What is a keyword in Python?",
 "A keyword is a reserved word like `if`, `for`, `return` that cannot be used as a variable name.",
 "**Mnemonic:** Killer Words Deny Use"),

("What is an identifier?",
 "A name used to identify variables, functions, classes, etc. Must follow naming rules.",
 "**Mnemonic:** Identity Names Everything"),

("What are the naming rules for identifiers?",
 "Start with letter or underscore, followed by letters, digits, or underscores. Cannot be a keyword.",
 "**Mnemonic:** Start With Letters, Don't Use Keywords"),

# 1.4 Variable Assignment
("How does Python assign variables?",
 "By reference — variable names point to objects in memory.",
 "**Mnemonic:** Assignment Points Internally"),

("How do you perform multiple assignment?",
 "Use comma-separated values:\n```python\na, b = 1, 2\nx = y = z = 0\n```",
 "**Mnemonic:** Many Bindings, One Line"),

("How do you swap variables in Python?",
 "Use tuple unpacking:\n```python\na, b = b, a\n```",
 "**Mnemonic:** Assign Backwards to Swap"),

# 1.5 = vs ==
("What does `=` do in Python?",
 "It assigns a value to a variable.",
 "**Mnemonic:** Equals Assigns"),

("What does `==` do?",
 "It compares two values for equality.",
 "**Mnemonic:** Double Equals Examines"),

("What’s an example of assignment vs comparison?",
 "```python\nx = 5\nx == 5  # True\n```",
 "**Mnemonic:** One Stores, Two Compares"),

# 1.6 Comments and Docstrings
("How do you write a single-line comment?",
 "Use `#` to begin the comment, continues to end of line.",
 "**Mnemonic:** Sharp Stops Reading"),

("How do you write multiline comments or docstrings?",
 "Use triple quotes `'''` or `\"\"\"`. If first in function/module/class, becomes the docstring.",
 "**Mnemonic:** Triple Quotes Teach"),

("What is a docstring?",
 "It’s the first string in a module/class/function — stored in `__doc__`.",
 "**Mnemonic:** Document Lives First"),

# 1.7 Summary Concepts
("What are valid identifiers?",
 "Letters, digits, and underscores. Cannot start with a digit or be a keyword.",
 "**Mnemonic:** Digits Don't Start"),

("What is the difference between assignment and equality?",
 "`=` is for assignment, `==` is for comparison.",
 "**Mnemonic:** Equals Examines, Assigns Assign"),

("What kind of file is a Python source file?",
 "A `.py` file, interpreted as a module.",
 "**Mnemonic:** Python Yields Modules"),

("What does UTF-8 encoding enable?",
 "It allows Unicode characters in the source code.",
 "**Mnemonic:** Unicode Turtles Fly 8 Directions"),

("What is the typical file path variable?",
 "`__file__` gives the path of the running file.",
 "**Mnemonic:** File Is Location Evidence"),
]
index = 0
showing_answer = False
output = widgets.Output()

# Buttons
prev_button = widgets.Button(description="◀️ Previous")
show_button = widgets.Button(description="Show Answer 👁️")
next_button = widgets.Button(description="Next ▶️")
restart_button = widgets.Button(description="🔁 Restart")
restart_button.layout.display = 'none'  # Hidden initially

def update_card():
    with output:
        clear_output(wait=True)
        question, answer, mnemonic = flashcards[index]
        display(Markdown(f"**Q:** {question}"))
        if showing_answer:
            display(Markdown(f"\n---\n\n**A:** {answer}\n\n{mnemonic}"))

    # Update button states
    prev_button.disabled = index == 0
    next_button.disabled = False  # always enabled unless at end
    show_button.description = "Hide Answer 🙈" if showing_answer else "Show Answer 👁️"

def show_toggle(_):
    global showing_answer
    showing_answer = not showing_answer
    update_card()

def next_card(_):
    global index, showing_answer
    if index < len(flashcards) - 1:
        index += 1
        showing_answer = False
        update_card()
    else:
        with output:
            clear_output()
            display(Markdown("🎉 **You've reached the end of the flashcards.**"))
        show_button.layout.display = 'none'
        next_button.layout.display = 'none'
        prev_button.layout.display = 'none'
        restart_button.layout.display = ''

def prev_card(_):
    global index, showing_answer
    if index > 0:
        index -= 1
        showing_answer = False
        update_card()

def restart(_):
    global index, showing_answer
    index = 0
    showing_answer = False
    show_button.layout.display = ''
    next_button.layout.display = ''
    prev_button.layout.display = ''
    restart_button.layout.display = 'none'
    update_card()

# Attach handlers
show_button.on_click(show_toggle)
next_button.on_click(next_card)
prev_button.on_click(prev_card)
restart_button.on_click(restart)

# Initialize display
update_card()
display(widgets.HBox([prev_button, show_button, next_button, restart_button]), output)

# %% [markdown]
# # 🧠 Section 2: Python Data Types
#
# ---
#
# ## 🔹 2.1 What Is a Data Type?
#
# A **data type** defines:
#
# - What kind of value an object holds
# - What operations can be performed on it
#
# In Python, everything is an object, and each object has a type:
#
# ```python
# type(42)  # <class 'int'>
# ```
#
# ---
#
# ## 🔹 2.2 Classification of Python Data Types
#
# ### ✅ A. Scalar / Atomic Types
#
# | Type      | Description                    | Example      | Mutable |
# |-----------|--------------------------------|--------------|---------|
# | `int`     | Arbitrary-precision integer    | `42`         | ❌      |
# | `float`   | 64-bit IEEE floating point     | `3.14`       | ❌      |
# | `complex` | Complex numbers (real + imag)  | `2 + 3j`     | ❌      |
# | `bool`    | Subclass of int                | `True`       | ❌      |
# | `NoneType`| Represents null / void         | `None`       | ❌      |
#
# ---
#
# ### ✅ B. Sequence Types
#
# | Type     | Description                | Example        | Mutable |
# |----------|----------------------------|----------------|---------|
# | `str`    | Unicode text               | `"hello"`      | ❌      |
# | `list`   | Ordered, indexed collection| `[1, 2, 3]`    | ✅      |
# | `tuple`  | Immutable sequence         | `(1, 2, 3)`    | ❌      |
# | `range`  | Lazy iterable of integers  | `range(5)`     | ❌      |
#
# ---
#
# ### ✅ C. Mapping Type
#
# | Type   | Description             | Example                | Mutable |
# |--------|-------------------------|------------------------|---------|
# | `dict` | Key-value hash table    | `{"a": 1, "b": 2}`     | ✅      |
#
# ---
#
# ### ✅ D. Set Types
#
# | Type        | Description               | Example             | Mutable |
# |-------------|---------------------------|---------------------|---------|
# | `set`       | Unordered unique elements | `{1, 2, 3}`         | ✅      |
# | `frozenset` | Immutable version of set  | `frozenset([1, 2])` | ❌      |
#
# ---
#
# ### ✅ E. Binary Types
#
# | Type         | Description                | Example                  | Mutable |
# |--------------|----------------------------|--------------------------|---------|
# | `bytes`      | Immutable binary sequence  | `b"abc"`                 | ❌      |
# | `bytearray`  | Mutable binary sequence    | `bytearray(b"abc")`      | ✅      |
# | `memoryview` | View into binary object    | `memoryview(b"abc")`     | ✅*     |
#
# > \* `memoryview` is only partially mutable depending on its source.
#
# ---
#
# ## 🔹 2.3 Type Relationships
#
# - `bool` is a subclass of `int`
#
# ```python
# isinstance(True, int)  # True
# ```
#
# - `tuple` and `list` are both iterable, indexed, and ordered
# - `dict`, `set`, `list`, etc. use **hashing** and **equality** rules internally
#
# ---
#
# ## 🔹 2.4 Mutability Overview
#
# | Type Class                        | Mutable |
# |----------------------------------|---------|
# | `int`, `float`, `complex`, `bool`, `NoneType` | ❌      |
# | `str`, `tuple`, `range`, `frozenset`, `bytes` | ❌      |
# | `list`, `dict`, `set`, `bytearray`, `memoryview` | ✅  |
#
# ---
#
# ## 🔹 2.5 Type Conversion
#
# ```python
# int("10")          # 10
# str(3.14)          # "3.14"
# list("abc")        # ['a', 'b', 'c']
# set([1, 2, 2, 3])  # {1, 2, 3}
# ```
#
# Edge case:
#
# ```python
# int("10.0")  # ValueError
# ```
#
# ---
#
# ## 🔹 2.6 Edge Cases & Notes
#
# - `int` can grow arbitrarily large (no overflow):
#
# ```python
# 10**100  # works fine
# ```
#
# - `float('nan')`, `float('inf')` supported:
#
# ```python
# float('inf') > 1e308  # True
# ```
#
# - `set()` removes duplicates:
#
# ```python
# set([1, 1, 2])  # {1, 2}
# ```
#
# - `dict` keys must be hashable:
#
# ```python
# d = { (1, 2): "ok" }    # ✅ tuple is hashable
# d = { [1, 2]: "fail" }  # ❌ TypeError — list is unhashable
# ```
#
# ---
#
# ## ✅ Summary Table (All Core & Advanced Types)
#
# | Category   | Types                                  |
# |------------|-----------------------------------------|
# | Numeric    | `int`, `float`, `complex`, `bool`       |
# | Text       | `str`                                   |
# | Sequences  | `list`, `tuple`, `range`                |
# | Set        | `set`, `frozenset`                      |
# | Mapping    | `dict`                                  |
# | Binary     | `bytes`, `bytearray`, `memoryview`      |
# | Special    | `NoneType`                              |

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

# (question, answer, PEMDAS-style mnemonic)
flashcards = [
# 2.1 What is a Data Type
("What is a data type in Python?",
 "It defines the kind of value an object holds and what operations can be performed on it.",
 "**Mnemonic:** Definitions Tell Python Actions"),

("Is everything an object in Python?",
 "Yes — all values in Python are objects with types.",
 "**Mnemonic:** Objects Always Have Types"),

("How do you check an object’s type?",
 "Use `type(x)` to return the object’s type.",
 "**Mnemonic:** Type Returns Class"),

# 2.2 Scalar / Atomic Types
("What are Python's scalar types?",
 "`int`, `float`, `complex`, `bool`, `NoneType`",
 "**Mnemonic:** I Feel Calm But Numb"),

("Is `int` mutable?",
 "No — it’s immutable and supports arbitrary precision.",
 "**Mnemonic:** Integers Never Break"),

("What is `bool` a subclass of?",
 "`bool` is a subclass of `int` — `True == 1`, `False == 0`.",
 "**Mnemonic:** Booleans Use Integers"),

("What does `NoneType` represent?",
 "It represents the absence of a value — `None`.",
 "**Mnemonic:** Null Only Needs Explanation"),

# 2.2 Sequence Types
("What are the core sequence types?",
 "`str`, `list`, `tuple`, `range`",
 "**Mnemonic:** Strings Like To Repeat"),

("Which sequence types are immutable?",
 "`str`, `tuple`, `range`",
 "**Mnemonic:** Sequences Typically Resist Change"),

("Which sequence type is mutable?",
 "`list` — can be changed after creation.",
 "**Mnemonic:** Lists Like Change"),

# 2.2 Mapping Type
("What is the primary mapping type?",
 "`dict` — a mutable key-value hash table.",
 "**Mnemonic:** Dictionaries Include Keys"),

# 2.2 Set Types
("What are the set types in Python?",
 "`set` (mutable) and `frozenset` (immutable)",
 "**Mnemonic:** Sets Freeze Softly"),

("Do sets allow duplicates?",
 "No — they automatically remove duplicates.",
 "**Mnemonic:** Sets Eliminate Twins"),

# 2.2 Binary Types
("What are the binary types?",
 "`bytes`, `bytearray`, `memoryview`",
 "**Mnemonic:** Binary Buffers Matter"),

("Which binary types are mutable?",
 "`bytearray` and `memoryview` (partially)",
 "**Mnemonic:** Buffers May Alter"),

("Is `bytes` mutable?",
 "No — `bytes` is immutable.",
 "**Mnemonic:** Bytes Remain Sealed"),

# 2.3 Type Relationships
("Is `bool` a subclass of `int`?",
 "Yes — `isinstance(True, int)` is `True`.",
 "**Mnemonic:** Booleans Act Like Integers"),

("How are `tuple` and `list` similar?",
 "Both are ordered, indexed, and iterable.",
 "**Mnemonic:** Tuple List Index Everything"),

("What do `dict`, `set`, `list` use internally?",
 "They rely on hashing and equality comparisons.",
 "**Mnemonic:** Hash Equals Structure"),

# 2.4 Mutability Overview
("Which types are immutable?",
 "`int`, `float`, `complex`, `bool`, `NoneType`, `str`, `tuple`, `range`, `frozenset`, `bytes`",
 "**Mnemonic:** If Frozen Code Behaves, No Trouble From Bytes"),

("Which types are mutable?",
 "`list`, `dict`, `set`, `bytearray`, `memoryview`",
 "**Mnemonic:** Lists Define Structures Best Mutable"),

# 2.5 Type Conversion
("How do you convert between types?",
 "Use built-in constructors like `int()`, `str()`, `list()`, `set()`.",
 "**Mnemonic:** Transform Inputs Cleanly"),

("What does `int('10.0')` raise?",
 "`ValueError` — cannot convert string float to int directly.",
 "**Mnemonic:** Ints Demand Pure Strings"),

("What does `set([1,2,2,3])` return?",
 "`{1, 2, 3}` — duplicates removed.",
 "**Mnemonic:** Sets Keep Unique"),

# 2.6 Edge Cases
("Can Python `int` overflow?",
 "No — it supports arbitrary precision.",
 "**Mnemonic:** Infinity Needs Time"),

("What does `float('inf')` return?",
 "`inf`, a special floating point constant for infinity.",
 "**Mnemonic:** Float Is Never Finite"),

("What does `float('nan')` mean?",
 "`NaN` — Not a Number.",
 "**Mnemonic:** Not A Number"),

("Can a tuple be a dict key?",
 "Yes — if all its elements are hashable.",
 "**Mnemonic:** Tuples Pass the Test"),

("Can a list be a dict key?",
 "No — lists are unhashable and raise `TypeError`.",
 "**Mnemonic:** Lists Break Dicts"),

# 2.6 Summary Table
("What are the numeric types?",
 "`int`, `float`, `complex`, `bool`",
 "**Mnemonic:** Integers Form Core Base"),

("What are the text and sequence types?",
 "`str`, `list`, `tuple`, `range`",
 "**Mnemonic:** Strings Link To Ranges"),

("What are the binary types?",
 "`bytes`, `bytearray`, `memoryview`",
 "**Mnemonic:** Binary Bytes Matter"),

("What is the only value of `NoneType`?",
 "`None` — used to indicate no value.",
 "**Mnemonic:** Nothing Ever Returns Something")
]
index = 0
showing_answer = False
output = widgets.Output()

# Buttons
prev_button = widgets.Button(description="◀️ Previous")
show_button = widgets.Button(description="Show Answer 👁️")
next_button = widgets.Button(description="Next ▶️")
restart_button = widgets.Button(description="🔁 Restart")
restart_button.layout.display = 'none'  # Hidden initially

def update_card():
    with output:
        clear_output(wait=True)
        question, answer, mnemonic = flashcards[index]
        display(Markdown(f"**Q:** {question}"))
        if showing_answer:
            display(Markdown(f"\n---\n\n**A:** {answer}\n\n{mnemonic}"))

    # Update button states
    prev_button.disabled = index == 0
    next_button.disabled = False  # always enabled unless at end
    show_button.description = "Hide Answer 🙈" if showing_answer else "Show Answer 👁️"

def show_toggle(_):
    global showing_answer
    showing_answer = not showing_answer
    update_card()

def next_card(_):
    global index, showing_answer
    if index < len(flashcards) - 1:
        index += 1
        showing_answer = False
        update_card()
    else:
        with output:
            clear_output()
            display(Markdown("🎉 **You've reached the end of the flashcards.**"))
        show_button.layout.display = 'none'
        next_button.layout.display = 'none'
        prev_button.layout.display = 'none'
        restart_button.layout.display = ''

def prev_card(_):
    global index, showing_answer
    if index > 0:
        index -= 1
        showing_answer = False
        update_card()

def restart(_):
    global index, showing_answer
    index = 0
    showing_answer = False
    show_button.layout.display = ''
    next_button.layout.display = ''
    prev_button.layout.display = ''
    restart_button.layout.display = 'none'
    update_card()

# Attach handlers
show_button.on_click(show_toggle)
next_button.on_click(next_card)
prev_button.on_click(prev_card)
restart_button.on_click(restart)

# Initialize display
update_card()
display(widgets.HBox([prev_button, show_button, next_button, restart_button]), output)

# %% [markdown]
# # 🧠 Section 3: Control Flow and Truthiness (with Theory)
#
# ---
#
# ## 🔹 3.1 `if` / `elif` / `else`
#
# ### 🧠 Theory:
#
# Python uses conditional statements to control which block of code runs based on the result of a Boolean expression.
#
# ```python
# x = 5
#
# if x > 10:
#     print("Big")
# elif x == 5:
#     print("Exact match")
# else:
#     print("Small")
# ```
#
# - Python checks conditions **top-down**
# - The **first** condition that evaluates to `True` runs
# - Remaining branches are skipped
#
# ---
#
# ## 🔹 3.2 Boolean Operators
#
# ### 🧠 Theory:
#
# Boolean operators `and`, `or`, and `not` allow combining or negating expressions. Python uses **short-circuit logic**, meaning evaluation stops as soon as the result is known.
#
# | Operator | Meaning                 | Example             | Result  |
# |----------|-------------------------|---------------------|---------|
# | `and`    | Both sides must be true | `True and False`    | `False` |
# | `or`     | One side must be true   | `False or 5`        | `5`     |
# | `not`    | Invert truth value      | `not []`            | `True`  |
#
# ---
#
# ## 🔹 3.3 Truthiness by Type
#
# ### 🧠 Theory:
#
# Any object in Python can be used in a condition.
# Python internally uses:
#
# ```python
# bool(obj)  # calls obj.__bool__() or obj.__len__()
# ```
#
# ### Falsy values include:
#
# - `False`, `None`
# - `0`, `0.0`, `0j`
# - `""`, `[]`, `()`, `{}`, `set()`, `range(0)`
# - `b""`, `bytearray()`, `memoryview(b"")`
#
# | Type  | Falsy Example | Truthy Example    |
# |-------|---------------|-------------------|
# | `int` | `0`           | `-1`              |
# | `str` | `""`          | `"hello"`         |
# | `list`| `[]`          | `[0]`             |
# | `dict`| `{}`          | `{"a": 1}`        |
# | `bytes`| `b""`        | `b"a"`            |
#
# ---
#
# ## 🔹 3.4 Ternary Expressions
#
# ### 🧠 Theory:
#
# Python allows a compact **one-line if/else** expression for assigning or returning values.
#
# ```python
# msg = "even" if x % 2 == 0 else "odd"
# ```
#
# This is equivalent to:
#
# ```python
# if x % 2 == 0:
#     msg = "even"
# else:
#     msg = "odd"
# ```
#
# ---
#
# ## 🔹 3.5 Nested Conditions
#
# ### 🧠 Theory:
#
# You can place `if` blocks inside other `if` blocks to handle more complex logic.
#
# ```python
# if user:
#     if age > 18:
#         print("Adult user")
# ```
#
# - Nesting allows conditional branches within other branches
# - Deep nesting should generally be avoided for clarity
#
# ---
#
# ## ✅ Summary
#
# - Python uses `bool(x)` to evaluate conditions
# - Most types are **truthy** unless **empty or explicitly falsy**
# - `if`, `elif`, `else` statements control conditional execution
# - Logical operators (`and`, `or`, `not`) are **expression-based** and **short-circuit**
# - Ternary expressions offer **inline conditional logic**

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

# (question, answer, PEMDAS-style mnemonic)
flashcards = [
("What are the main control flow topics in Python?",
  "Python's control flow includes:\n"
  "• if / elif / else (e.g., `if x > 0: ... elif x == 0: ... else: ...`)\n"
  "• Boolean operators (e.g., `x and y`, `x or y`, `not x`)\n"
  "• Truthiness and falsy values (e.g., `bool([]) → False`, `bool(1) → True`)\n"
  "• Ternary expressions (e.g., `'even' if n % 2 == 0 else 'odd'`)\n"
  "• Nested conditionals (e.g., `if x: if y: ... else: ...`)\n"
  "• Summary rules (e.g., `bool(obj)` uses `__bool__()` or `__len__()`)",
  "**Mnemonic:** If Bob Thinks Ternary Nesting Sucks"),
# 3.1 if / elif / else
("How does Python execute an if/elif/else block?",
 "Conditions are evaluated top-down. The first `True` block runs, and the rest are skipped.",
 "**Mnemonic:** First True Fires"),

("What is the basic syntax of an if-statement?",
 "```python\nif x > 0:\n    ...\nelif x == 0:\n    ...\nelse:\n    ...\n```",
 "**Mnemonic:** If Elif Else Always Ends"),

("Are all branches in an if/elif/else block checked?",
 "No — only the first matching condition is executed.",
 "**Mnemonic:** Stop At First Match"),

# 3.2 Boolean Operators
("What does the `and` operator do?",
 "Returns the second operand if the first is true; otherwise returns the first.",
 "**Mnemonic:** All Need Double Truth"),

("What does the `or` operator do?",
 "Returns the first truthy operand; if none, returns the last.",
 "**Mnemonic:** One Result Early"),

("What does `not` do?",
 "Returns the inverse boolean value: `not True → False`.",
 "**Mnemonic:** Negate Our Thought"),

("What is short-circuit evaluation?",
 "Python stops evaluating once the outcome is determined (left to right).",
 "**Mnemonic:** Short Conditions Cut"),

# 3.3 Truthiness by Type
("How does Python determine truthiness?",
 "By calling `bool(obj)`, which uses `__bool__()` or `__len__()`.",
 "**Mnemonic:** Boolean Uses Length"),

("What values are falsy in Python?",
 "`False`, `None`, `0`, `0.0`, `0j`, `''`, `[]`, `()`, `{}`, `set()`, `range(0)`, `b''`, `bytearray()`, `memoryview(b'')`",
 "**Mnemonic:** Few Numbers Strings Lists Dicts Empty"),

("Is `0` truthy?",
 "No — it is a falsy numeric value.",
 "**Mnemonic:** Zero Lies"),

("Is `[]` truthy?",
 "No — empty sequences are falsy.",
 "**Mnemonic:** Empty Lists Lie"),

("Is `[0]` truthy?",
 "Yes — non-empty lists are always truthy, regardless of contents.",
 "**Mnemonic:** Content Doesn’t Matter"),

("Is `""` falsy?",
 "Yes — empty strings are falsy.",
 "**Mnemonic:** Silent Strings Are Lies"),

("Is `None` falsy?",
 "Yes — always falsy.",
 "**Mnemonic:** Nothing Never Passes"),

# 3.4 Ternary Expressions
("What is a ternary expression?",
 "A one-line if/else expression:\n```python\nx = 'even' if n % 2 == 0 else 'odd'\n```",
 "**Mnemonic:** Ternary Evaluates Reasonable Needs"),

("Does ternary replace full if/else?",
 "No — it’s best for simple value expressions, not block execution.",
 "**Mnemonic:** Inline Only"),

# 3.5 Nested Conditions
("What are nested if-statements?",
 "An if/elif/else block inside another — used for multi-level logic.",
 "**Mnemonic:** Nest If Needed"),

("Is nesting if-statements bad?",
 "Use sparingly — too much nesting hurts readability. Use logical operators when possible.",
 "**Mnemonic:** Too Deep Damages Clarity"),

# 3.6 Summary
("What does Python use to evaluate conditionals?",
 "`bool(x)` — most objects are truthy unless empty or explicitly False.",
 "**Mnemonic:** Boolean On Object Length"),

("Which types are always falsy when empty?",
 "`str`, `list`, `dict`, `set`, `tuple`, `range`, `bytes`, `bytearray`, `memoryview`",
 "**Mnemonic:** Empty Containers Never Lie"),

("What’s the difference between `== False` and `not x`?",
 "`not x` checks truthiness; `x == False` checks strict value comparison.",
 "**Mnemonic:** Not Means Truth Test"),

("Why do `and` and `or` return values (not just True/False)?",
 "They return actual operands, not coerced bools — useful in expressions.",
 "**Mnemonic:** Logic Operators Yield Values")
]
index = 0
showing_answer = False
output = widgets.Output()

# Buttons
prev_button = widgets.Button(description="◀️ Previous")
show_button = widgets.Button(description="Show Answer 👁️")
next_button = widgets.Button(description="Next ▶️")
restart_button = widgets.Button(description="🔁 Restart")
restart_button.layout.display = 'none'  # Hidden initially

def update_card():
    with output:
        clear_output(wait=True)
        question, answer, mnemonic = flashcards[index]
        display(Markdown(f"**Q:** {question}"))
        if showing_answer:
            display(Markdown(f"\n---\n\n**A:** {answer}\n\n{mnemonic}"))

    # Update button states
    prev_button.disabled = index == 0
    next_button.disabled = False  # always enabled unless at end
    show_button.description = "Hide Answer 🙈" if showing_answer else "Show Answer 👁️"

def show_toggle(_):
    global showing_answer
    showing_answer = not showing_answer
    update_card()

def next_card(_):
    global index, showing_answer
    if index < len(flashcards) - 1:
        index += 1
        showing_answer = False
        update_card()
    else:
        with output:
            clear_output()
            display(Markdown("🎉 **You've reached the end of the flashcards.**"))
        show_button.layout.display = 'none'
        next_button.layout.display = 'none'
        prev_button.layout.display = 'none'
        restart_button.layout.display = ''

def prev_card(_):
    global index, showing_answer
    if index > 0:
        index -= 1
        showing_answer = False
        update_card()

def restart(_):
    global index, showing_answer
    index = 0
    showing_answer = False
    show_button.layout.display = ''
    next_button.layout.display = ''
    prev_button.layout.display = ''
    restart_button.layout.display = 'none'
    update_card()

# Attach handlers
show_button.on_click(show_toggle)
next_button.on_click(next_card)
prev_button.on_click(prev_card)
restart_button.on_click(restart)

# Initialize display
update_card()
display(widgets.HBox([prev_button, show_button, next_button, restart_button]), output)

# %% [markdown]
# # 🧠 Section 4: Loops and Iteration
#
# This section covers:
#
# - `for` and `while` loops
# - Loop control (`break`, `continue`, `else`)
# - Iterating over different data types
# - Basic loop internals
#
# ---
#
# ## 🔹 4.1 `for` Loops
#
# ### 🧠 Theory:
#
# A `for` loop iterates over any **iterable** (e.g., list, string, range) one item at a time.
#
# ```python
# for x in [1, 2, 3]:
#     print(x)
# ```
#
# - Python internally calls `iter()` on the object, then repeatedly calls `next()` until `StopIteration`.
#
# ### ✅ Common Iterables:
#
# ```python
# for c in "abc":        # characters
# for i in range(3):     # 0, 1, 2
# for key in {"a": 1}:   # keys in dict
# for x in [10, 20, 30]: # list items
# ```
#
# ---
#
# ## 🔹 4.2 `while` Loops
#
# ### 🧠 Theory:
#
# A `while` loop runs as long as its condition evaluates to `True`.
#
# ```python
# x = 0
# while x < 3:
#     print(x)
#     x += 1
# ```
#
# - Use `while` when the number of iterations isn't predetermined.
#
# ---
#
# ## 🔹 4.3 Loop Control: `break` and `continue`
#
# ### 🧠 Theory:
#
# - `break` exits the loop **immediately**
# - `continue` skips to the **next iteration**
#
# ```python
# for i in range(5):
#     if i == 3:
#         break
#     print(i)
# ```
#
# ```python
# for i in range(5):
#     if i == 2:
#         continue
#     print(i)
# ```
#
# ---
#
# ## 🔹 4.4 `else` on Loops
#
# ### 🧠 Theory:
#
# Python supports an `else` block **after `for` or `while`**, which only runs **if the loop did not hit `break`**.
#
# ```python
# for i in range(3):
#     if i == 5:
#         break
# else:
#     print("Loop completed")
# ```
#
# - ✅ Useful for **loop-else search patterns** (e.g., checking if an item was found).
#
# ---
#
# ## 🔹 4.5 `enumerate()` and `zip()`
#
# ```python
# for i, val in enumerate(["a", "b"]):
#     print(i, val)
#
# for a, b in zip([1, 2], ["x", "y"]):
#     print(a, b)
# ```
#
# - `enumerate()` gives `(index, item)`
# - `zip()` joins multiple iterables into parallel tuples
#
# ---
#
# ## 🔹 4.6 Infinite Loops (with `while True`)
#
# ```python
# while True:
#     cmd = input()
#     if cmd == "exit":
#         break
# ```
#
# - Use with caution — always include a `break` condition to prevent hangs
#
# ---
#
# ## ✅ Summary Table
#
# | Construct       | Use Case                          |
# |------------------|-----------------------------------|
# | `for`            | Known-size iteration              |
# | `while`          | Condition-based iteration         |
# | `break`          | Exit loop early                   |
# | `continue`       | Skip rest of current iteration    |
# | `else after loop`| Run if loop completes without `break` |
# | `enumerate()`    | Index + item during iteration     |
# | `zip()`          | Parallel iteration over multiple iterables |

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

# (question, answer, PEMDAS-style mnemonic)
flashcards = [
# 4.1 for Loops
("How does a for loop work in Python?",
 "It iterates over any iterable by calling `iter()` and repeatedly calling `next()` until `StopIteration`.",
 "**Mnemonic:** For Iterates Next Until Stop"),

("What are common iterables for a for loop?",
 "Strings, ranges, lists, tuples, sets, dictionaries, etc.",
 "**Mnemonic:** Strings Really Love To Serve Dictionaries"),

("Does a for loop require an index?",
 "No — Python loops directly over elements unless you use `enumerate()`.",
 "**Mnemonic:** Index Optional Unless Asked"),

# 4.2 while Loops
("How does a while loop work?",
 "It repeats as long as the condition is `True`. Used when the number of iterations is unknown.",
 "**Mnemonic:** While Holds A Logical Expression"),

("When should you use a while loop instead of for?",
 "When you don’t know how many iterations you need up front.",
 "**Mnemonic:** While When Uncertain"),

("Can while loops become infinite?",
 "Yes — use `while True:` cautiously and include a break condition.",
 "**Mnemonic:** Infinite Means Include Exit"),

# 4.3 break and continue
("What does `break` do in a loop?",
 "Immediately exits the nearest enclosing loop.",
 "**Mnemonic:** Break Ends Loop"),

("What does `continue` do?",
 "Skips the rest of the current iteration and continues with the next.",
 "**Mnemonic:** Continue Ignores Then Iterates"),

("What’s a good use case for `break`?",
 "To exit early during search or validation loops.",
 "**Mnemonic:** Break When Found"),

# 4.4 else on Loops
("When does a loop’s `else` block run?",
 "Only if the loop completes without hitting `break`.",
 "**Mnemonic:** Else Loves Safe Exit"),

("What’s a use case for for-else?",
 "Searching: `else` runs only if no item matched and `break` wasn’t triggered.",
 "**Mnemonic:** Else Finds Failure"),

# 4.5 enumerate() and zip()
("What does `enumerate()` do?",
 "It returns `(index, value)` pairs from an iterable.",
 "**Mnemonic:** Enumerate Numbers Every Item"),

("What does `zip()` do?",
 "It combines multiple iterables into tuples.",
 "**Mnemonic:** Zip Inputs Parallel"),

("What is the result of `zip([1,2], ['a','b'])`?",
 "`[(1, 'a'), (2, 'b')]` — parallel iteration over both lists.",
 "**Mnemonic:** Zip Aligns Pairs"),

# 4.6 Infinite Loops
("How do you create an infinite loop in Python?",
 "`while True:` — runs forever unless a `break` is used inside.",
 "**Mnemonic:** True Means Forever"),

("What’s the danger of infinite loops?",
 "If no `break` is included, the loop never ends and can crash or hang.",
 "**Mnemonic:** Forever Loops Must Stop"),

# 4.7 Summary Concepts
("What is `break` used for?",
 "To exit a loop early when a condition is met.",
 "**Mnemonic:** Break Stops Now"),

("What is `continue` used for?",
 "To skip the rest of the loop body and move to the next item.",
 "**Mnemonic:** Continue Skips Ahead"),

("When should you use a `for` loop?",
 "When you know the number of elements to iterate.",
 "**Mnemonic:** For Knows Size"),

("When should you use a `while` loop?",
 "When looping based on a condition — number of iterations unknown.",
 "**Mnemonic:** While Waits for False"),

("When does a `for` loop use `else`?",
 "When the loop finishes naturally (no `break`), the `else` block executes.",
 "**Mnemonic:** Else Executes Peacefully"),

("What happens if `zip()` inputs differ in length?",
 "It stops at the shortest input.",
 "**Mnemonic:** Zip Ends With Shortest")
]
index = 0
showing_answer = False
output = widgets.Output()

# Buttons
prev_button = widgets.Button(description="◀️ Previous")
show_button = widgets.Button(description="Show Answer 👁️")
next_button = widgets.Button(description="Next ▶️")
restart_button = widgets.Button(description="🔁 Restart")
restart_button.layout.display = 'none'  # Hidden initially

def update_card():
    with output:
        clear_output(wait=True)
        question, answer, mnemonic = flashcards[index]
        display(Markdown(f"**Q:** {question}"))
        if showing_answer:
            display(Markdown(f"\n---\n\n**A:** {answer}\n\n{mnemonic}"))

    # Update button states
    prev_button.disabled = index == 0
    next_button.disabled = False  # always enabled unless at end
    show_button.description = "Hide Answer 🙈" if showing_answer else "Show Answer 👁️"

def show_toggle(_):
    global showing_answer
    showing_answer = not showing_answer
    update_card()

def next_card(_):
    global index, showing_answer
    if index < len(flashcards) - 1:
        index += 1
        showing_answer = False
        update_card()
    else:
        with output:
            clear_output()
            display(Markdown("🎉 **You've reached the end of the flashcards.**"))
        show_button.layout.display = 'none'
        next_button.layout.display = 'none'
        prev_button.layout.display = 'none'
        restart_button.layout.display = ''

def prev_card(_):
    global index, showing_answer
    if index > 0:
        index -= 1
        showing_answer = False
        update_card()

def restart(_):
    global index, showing_answer
    index = 0
    showing_answer = False
    show_button.layout.display = ''
    next_button.layout.display = ''
    prev_button.layout.display = ''
    restart_button.layout.display = 'none'
    update_card()

# Attach handlers
show_button.on_click(show_toggle)
next_button.on_click(next_card)
prev_button.on_click(prev_card)
restart_button.on_click(restart)

# Initialize display
update_card()
display(widgets.HBox([prev_button, show_button, next_button, restart_button]), output)

# %% [markdown]
# # 🧠 Section 5: Functions and Arguments
#
# This section covers:
#
# - How to define and call functions
# - Function arguments (positional, keyword, default)
# - Return values
# - Variable scope
# - `*args` and `**kwargs` (advanced syntax preview)
#
# ---
#
# ## 🔹 5.1 Function Definition and Call
#
# ### 🧠 Theory:
#
# Functions are reusable blocks of code defined with `def` and executed when called by name.
#
# ```python
# def greet(name):
#     print("Hello", name)
#
# greet("Alice")
# ```
#
# ---
#
# ## 🔹 5.2 Return Values
#
# ### 🧠 Theory:
#
# `return` sends a result back to the caller and ends the function.
#
# ```python
# def add(a, b):
#     return a + b
#
# x = add(2, 3)  # x = 5
# ```
#
# - If no `return` is used, Python implicitly returns `None`.
#
# ---
#
# ## 🔹 5.3 Parameters and Arguments
#
# | Type       | Example         | Notes               |
# |------------|------------------|----------------------|
# | Positional | `add(1, 2)`      | Order matters        |
# | Keyword    | `add(a=1, b=2)`  | Explicit naming      |
# | Default    | `def f(x=0): ...`| Used when arg not passed |
#
# ```python
# def greet(name="Guest"):
#     print("Hello", name)
#
# greet()          # → Hello Guest
# greet("Alice")   # → Hello Alice
# ```
#
# ---
#
# ## 🔹 5.4 Variable Scope
#
# ### 🧠 Theory:
#
# - Variables created in a function are **local** to that function.
# - **Global** variables can be read inside a function.
# - To modify a global variable, use the `global` keyword.
#
# ```python
# x = 10
#
# def show():
#     print(x)  # reads global x
#
# def modify():
#     global x
#     x = 99    # modifies global x
# ```
#
# ---
#
# ## 🔹 5.5 `*args` and `**kwargs` (Preview)
#
# ### 🧠 Theory:
#
# - `*args`: captures extra **positional arguments** as a `tuple`
# - `**kwargs`: captures extra **keyword arguments** as a `dict`
#
# ```python
# def demo(*args, **kwargs):
#     print(args)
#     print(kwargs)
#
# demo(1, 2, a=3, b=4)
# # Output:
# # args = (1, 2)
# # kwargs = {'a': 3, 'b': 4}
# ```
#
# ---
#
# ## ✅ Summary Table
#
# | Concept     | Example         | Meaning                          |
# |-------------|------------------|----------------------------------|
# | `def`       | `def f():`       | Define a function                |
# | `return`    | `return x`       | Return a value                   |
# | Positional  | `f(1, 2)`        | Order matters                    |
# | Keyword     | `f(a=1, b=2)`    | Named arguments                  |
# | Default     | `def f(x=0)`     | Optional values                  |
# | `*args`     | `def f(*a)`      | Collect extra positional args    |
# | `**kwargs`  | `def f(**k)`     | Collect extra keyword args       |
# | Scope       | `global`, `local`, `nonlocal` | Controls variable visibility |

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

# (question, answer, PEMDAS-style mnemonic)
flashcards = [
# 5.1 Function Definition and Call
("How do you define a function in Python?",
 "Use `def` followed by the function name and parameters.\n```python\ndef greet(name):\n    print('Hello', name)\n```",
 "**Mnemonic:** Define Every Function"),

("How do you call a function?",
 "Use the function name followed by parentheses and any required arguments.\n```python\ngreet('Alice')\n```",
 "**Mnemonic:** Call Function Normally"),

("What is the purpose of a function?",
 "To encapsulate reusable code into named callable blocks.",
 "**Mnemonic:** Functions Help Avoid Repetition"),

# 5.2 Return Values
("What does `return` do?",
 "`return` sends a result back to the caller and exits the function.",
 "**Mnemonic:** Return Ends Execution"),

("What happens if no return is used?",
 "The function returns `None` by default.",
 "**Mnemonic:** No Return Means None"),

("Can you return multiple values?",
 "Yes — Python returns a tuple.\n```python\nreturn x, y\n```",
 "**Mnemonic:** Return Several Things"),

# 5.3 Parameters and Arguments
("What are positional arguments?",
 "Arguments passed in order — the position determines their role.\n```python\nadd(1, 2)\n```",
 "**Mnemonic:** Position Is Power"),

("What are keyword arguments?",
 "Arguments passed by explicitly naming them.\n```python\nadd(a=1, b=2)\n```",
 "**Mnemonic:** Keywords Allow Clarity"),

("What are default parameters?",
 "Parameters with default values that are used if not provided by the caller.\n```python\ndef greet(name='Guest'):\n```",
 "**Mnemonic:** Defaults Fill In"),

("Can you mix positional and keyword arguments?",
 "Yes — but positional must come first.",
 "**Mnemonic:** Positions Before Keywords"),

# 5.4 Variable Scope
("What is local scope?",
 "Variables defined inside a function are local and cannot be accessed outside.",
 "**Mnemonic:** Locals Live Inside"),

("What is global scope?",
 "Variables defined at the top level are global and accessible unless shadowed.",
 "**Mnemonic:** Global Goes Everywhere"),

("Can you modify global variables inside a function?",
 "Yes — but you must declare them with `global`.",
 "**Mnemonic:** Global Must Be Declared"),

("What happens without `global`?",
 "Assignment creates a new local variable, even if a global with the same name exists.",
 "**Mnemonic:** Assignment Means Local"),

# 5.5 *args and **kwargs
("What is `*args` used for?",
 "To collect extra positional arguments into a tuple.\n```python\ndef f(*args):\n    print(args)\n```",
 "**Mnemonic:** Args Receive Grouped Stuff"),

("What is `**kwargs` used for?",
 "To collect extra keyword arguments into a dictionary.\n```python\ndef f(**kwargs):\n    print(kwargs)\n```",
 "**Mnemonic:** Kwargs Wrap Around Reasoned Groups"),

("Can you use *args and **kwargs together?",
 "Yes — `*args` must come before `**kwargs`.",
 "**Mnemonic:** Stars Before Double Stars"),

("What is the type of `args` and `kwargs`?",
 "`args` is a tuple, `kwargs` is a dict.",
 "**Mnemonic:** Args Are Tuples, Kwargs Are Dicts"),

# 5.6 Summary
("What does `def` do?",
 "It defines a named function object.",
 "**Mnemonic:** Define Every Function"),

("What types of arguments can Python functions accept?",
 "Positional, keyword, default, *args, and **kwargs.",
 "**Mnemonic:** Functions Keep Parameters Flexible"),

("What does the `return` statement end?",
 "It ends the function’s execution and sends back a value.",
 "**Mnemonic:** Return Sends Result"),

("How does Python manage variable scope?",
 "Local by default; use `global` or `nonlocal` for wider visibility.",
 "**Mnemonic:** Scope Controls Reach"),

("What happens if you pass too many arguments?",
 "Python raises `TypeError` unless *args or **kwargs is used.",
 "**Mnemonic:** Too Many? Use Stars")
]
index = 0
showing_answer = False
output = widgets.Output()

# Buttons
prev_button = widgets.Button(description="◀️ Previous")
show_button = widgets.Button(description="Show Answer 👁️")
next_button = widgets.Button(description="Next ▶️")
restart_button = widgets.Button(description="🔁 Restart")
restart_button.layout.display = 'none'  # Hidden initially

def update_card():
    with output:
        clear_output(wait=True)
        question, answer, mnemonic = flashcards[index]
        display(Markdown(f"**Q:** {question}"))
        if showing_answer:
            display(Markdown(f"\n---\n\n**A:** {answer}\n\n{mnemonic}"))

    # Update button states
    prev_button.disabled = index == 0
    next_button.disabled = False  # always enabled unless at end
    show_button.description = "Hide Answer 🙈" if showing_answer else "Show Answer 👁️"

def show_toggle(_):
    global showing_answer
    showing_answer = not showing_answer
    update_card()

def next_card(_):
    global index, showing_answer
    if index < len(flashcards) - 1:
        index += 1
        showing_answer = False
        update_card()
    else:
        with output:
            clear_output()
            display(Markdown("🎉 **You've reached the end of the flashcards.**"))
        show_button.layout.display = 'none'
        next_button.layout.display = 'none'
        prev_button.layout.display = 'none'
        restart_button.layout.display = ''

def prev_card(_):
    global index, showing_answer
    if index > 0:
        index -= 1
        showing_answer = False
        update_card()

def restart(_):
    global index, showing_answer
    index = 0
    showing_answer = False
    show_button.layout.display = ''
    next_button.layout.display = ''
    prev_button.layout.display = ''
    restart_button.layout.display = 'none'
    update_card()

# Attach handlers
show_button.on_click(show_toggle)
next_button.on_click(next_card)
prev_button.on_click(prev_card)
restart_button.on_click(restart)

# Initialize display
update_card()
display(widgets.HBox([prev_button, show_button, next_button, restart_button]), output)

# %% [markdown]
# # 🧠 Section 6: Built-in Collections and Advanced Operations
#
# This section covers:
#
# - Python’s primary container types: `list`, `tuple`, `set`, `dict`
# - Indexing, slicing, and membership
# - Built-in methods and operations
# - Mutability, unpacking, and iteration behavior
#
# ---
#
# ## 🔹 6.1 Lists
#
# ### 🧠 Theory:
# A `list` is a **mutable**, **ordered** collection that allows **duplicates** and **indexing**.
#
# ```python
# fruits = ["apple", "banana", "cherry"]
# ```
#
# ### ✅ Common Operations:
#
# ```python
# fruits.append("grape")     # Add to end
# fruits[1] = "orange"       # Modify item
# del fruits[0]              # Delete by index
# "banana" in fruits         # Membership test → False
# ```
#
# ---
#
# ## 🔹 6.2 Tuples
#
# ### 🧠 Theory:
# A `tuple` is an **immutable**, **ordered** sequence. Often used for fixed or heterogeneous data.
#
# ```python
# point = (4, 5)
# ```
#
# ### ✅ Tuple Unpacking:
#
# ```python
# x, y = point
# ```
#
# ### ✅ Single-element Tuple:
#
# ```python
# t = (42,)  # Not just (42)
# ```
#
# ---
#
# ## 🔹 6.3 Sets
#
# ### 🧠 Theory:
# A `set` is an **unordered**, **unique** collection of hashable items.
#
# ```python
# s = {1, 2, 3}
# ```
#
# ### ✅ Set Operations:
#
# ```python
# s.add(4)            # Add item
# s.remove(2)         # Remove item
# {1, 2} | {2, 3}     # Union → {1, 2, 3}
# {1, 2} & {2, 3}     # Intersection → {2}
# ```
#
# - `frozenset()` is the **immutable** version of `set`.
#
# ---
#
# ## 🔹 6.4 Dictionaries
#
# ### 🧠 Theory:
# A `dict` is a **key-value store** with **fast lookups**. Keys must be hashable.
#
# ```python
# user = {"name": "Alice", "age": 30}
# ```
#
# ### ✅ Common Operations:
#
# ```python
# user["name"]         # "Alice"
# user.get("email")    # None (no error if missing)
# user["age"] = 31     # Update value
# del user["age"]      # Delete key
# ```
#
# - Keys must be **unique** — later keys overwrite earlier ones.
#
# ---
#
# ## 🔹 6.5 Indexing, Slicing, and Membership
#
# ```python
# a = [10, 20, 30, 40]
# a[0]      # 10
# a[-1]     # 40 (last element)
# a[1:3]    # [20, 30] (slice)
# 20 in a   # True
# ```
#
# ✅ Works on: `list`, `tuple`, `str`, `range`
#
# ---
#
# ## 🔹 6.6 Unpacking
#
# ```python
# a, b, c = [1, 2, 3]
# first, *middle, last = [1, 2, 3, 4, 5]
# ```
#
# ✅ Works with any **iterable**
# ✅ Useful for: parallel assignment, swapping, returns
#
# ---
#
# ## 🔹 6.7 Mutability Summary
#
# | Type       | Mutable? |
# |------------|----------|
# | `list`     | ✅ Yes   |
# | `tuple`    | ❌ No    |
# | `set`      | ✅ Yes   |
# | `frozenset`| ❌ No    |
# | `dict`     | ✅ Yes   |
#
# ---
#
# ## ✅ Summary Table
#
# | Type  | Ordered | Indexed | Mutable | Allows Duplicates |
# |-------|---------|---------|---------|--------------------|
# | list  | ✅      | ✅      | ✅      | ✅                 |
# | tuple | ✅      | ✅      | ❌      | ✅                 |
# | set   | ❌      | ❌      | ✅      | ❌                 |
# | dict  | ✅ (3.7+)| ✅ (keys) | ✅    | Keys: ❌, Values: ✅ |

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

# (question, answer, PEMDAS-style mnemonic)
flashcards = [
("What is a Python list?",
 "A mutable, ordered collection that allows duplicates and supports indexing.",
 "**Mnemonic:** Lists Keep Everything Ordered"),

("Can list items be changed?",
 "Yes — lists are mutable. You can add, remove, or update elements.",
 "**Mnemonic:** Lists Are Rewriteable"),

("What are common list operations?",
 "`append()`, `del`, item assignment, and membership tests like `'x' in list`.",
 "**Mnemonic:** Add Drop Swap Test"),

("Is membership check fast in lists?",
 "No — it's O(n) because lists are scanned sequentially.",
 "**Mnemonic:** Linear In List"),

# 6.2 Tuples
("What is a tuple?",
 "An immutable, ordered sequence — often used for fixed-size records.",
 "**Mnemonic:** Tuples Unchange Permanent"),

("Can you change tuple values?",
 "No — tuples are immutable.",
 "**Mnemonic:** Tuples Are Final"),

("How do you make a single-element tuple?",
 "Add a comma: `(42,)`",
 "**Mnemonic:** One Needs Comma"),

("Can tuples be unpacked?",
 "Yes — each element is assigned to a variable.\n```python\nx, y = (1, 2)\n```",
 "**Mnemonic:** Tuples Explode Into Variables"),

# 6.3 Sets
("What is a set in Python?",
 "An unordered collection of unique elements.",
 "**Mnemonic:** Sets Exclude Twins"),

("Do sets preserve order?",
 "No — sets are unordered and unindexed.",
 "**Mnemonic:** Sets Don’t Care Order"),

("What are common set operations?",
 "`add()`, `remove()`, union (`|`), intersection (`&`) etc.",
 "**Mnemonic:** Union And Removal Work"),

("What is a `frozenset`?",
 "An immutable version of a set.",
 "**Mnemonic:** Frozen Sets Stay Still"),

# 6.4 Dictionaries
("What is a dictionary?",
 "A key-value store with fast lookups. Keys must be hashable.",
 "**Mnemonic:** Dicts Index Content Transparently"),

("Can dict keys be duplicated?",
 "No — repeated keys overwrite earlier values.",
 "**Mnemonic:** Duplicate Keys Die"),

("How to safely access a key?",
 "Use `dict.get(key)` to avoid KeyError.",
 "**Mnemonic:** Get Guards Error"),

("Are dicts ordered?",
 "Yes — as of Python 3.7+, dicts preserve insertion order.",
 "**Mnemonic:** Dictionaries Track Order Now"),

# 6.5 Indexing, Slicing, Membership
("What is list indexing?",
 "Accessing a specific element via position.\n`a[0]` → first, `a[-1]` → last",
 "**Mnemonic:** Index Begins At Zero"),

("What does slicing return?",
 "A new subsequence of the original iterable.\n```python\na[1:3] → [item2, item3]\n```",
 "**Mnemonic:** Slice Skips End"),

("Which types support slicing?",
 "`list`, `tuple`, `str`, `range`",
 "**Mnemonic:** Slice These Regularly"),

("What does `'x' in a` test?",
 "It checks for membership — returns `True` if `x` exists in `a`.",
 "**Mnemonic:** Membership Inquires Entry"),

# 6.6 Unpacking
("What is unpacking?",
 "Assigning elements from an iterable to variables.\n```python\na, b = [1, 2]\n```",
 "**Mnemonic:** Unpack And Assign"),

("What does `a, *b, c = [1,2,3,4]` do?",
 "`a=1`, `b=[2,3]`, `c=4` — the star collects the middle.",
 "**Mnemonic:** Star Soaks Middle"),

("What can be unpacked?",
 "Any iterable: list, tuple, str, range, etc.",
 "**Mnemonic:** Iterables Explode Easily"),

# 6.7 Mutability Summary
("Which built-in collections are mutable?",
 "`list`, `set`, `dict`",
 "**Mnemonic:** Lists Store Dynamic"),

("Which built-in collections are immutable?",
 "`tuple`, `frozenset`",
 "**Mnemonic:** Frozen Tuples Stay"),

("Are dict values mutable?",
 "Yes — values can be any type. Keys must be immutable.",
 "**Mnemonic:** Dicts Vary, Keys Stable"),

# 6.8 Summary Table
("Which types are ordered and indexed?",
 "`list`, `tuple`, and `dict` (3.7+) — all preserve order and allow indexing.",
 "**Mnemonic:** Order Lives In Lists, Tuples, Dictionaries"),

("Which type allows duplicates?",
 "`list` and `tuple` allow duplicates, `set` does not.",
 "**Mnemonic:** Duplicates Live Twice"),

("Which type offers fastest lookup?",
 "`dict` and `set` — both use hashing for O(1) average-case access.",
 "**Mnemonic:** Hash Gives Speed")
]
index = 0
showing_answer = False
output = widgets.Output()

# Buttons
prev_button = widgets.Button(description="◀️ Previous")
show_button = widgets.Button(description="Show Answer 👁️")
next_button = widgets.Button(description="Next ▶️")
restart_button = widgets.Button(description="🔁 Restart")
restart_button.layout.display = 'none'  # Hidden initially

def update_card():
    with output:
        clear_output(wait=True)
        question, answer, mnemonic = flashcards[index]
        display(Markdown(f"**Q:** {question}"))
        if showing_answer:
            display(Markdown(f"\n---\n\n**A:** {answer}\n\n{mnemonic}"))

    # Update button states
    prev_button.disabled = index == 0
    next_button.disabled = False  # always enabled unless at end
    show_button.description = "Hide Answer 🙈" if showing_answer else "Show Answer 👁️"

def show_toggle(_):
    global showing_answer
    showing_answer = not showing_answer
    update_card()

def next_card(_):
    global index, showing_answer
    if index < len(flashcards) - 1:
        index += 1
        showing_answer = False
        update_card()
    else:
        with output:
            clear_output()
            display(Markdown("🎉 **You've reached the end of the flashcards.**"))
        show_button.layout.display = 'none'
        next_button.layout.display = 'none'
        prev_button.layout.display = 'none'
        restart_button.layout.display = ''

def prev_card(_):
    global index, showing_answer
    if index > 0:
        index -= 1
        showing_answer = False
        update_card()

def restart(_):
    global index, showing_answer
    index = 0
    showing_answer = False
    show_button.layout.display = ''
    next_button.layout.display = ''
    prev_button.layout.display = ''
    restart_button.layout.display = 'none'
    update_card()

# Attach handlers
show_button.on_click(show_toggle)
next_button.on_click(next_card)
prev_button.on_click(prev_card)
restart_button.on_click(restart)

# Initialize display
update_card()
display(widgets.HBox([prev_button, show_button, next_button, restart_button]), output)

# %% [markdown]
# # 🧠 Section 7: Comprehensions
#
# This section covers:
#
# - List, set, and dictionary comprehensions
# - Conditional comprehensions
# - Nested comprehensions
# - Generator expressions vs list comprehensions
#
# ---
#
# ## 🔹 7.1 What Is a Comprehension?
#
# ### 🧠 Theory:
#
# A **comprehension** is a compact syntax for creating a new sequence from an existing iterable.
#
# ✅ They are **faster**, **cleaner**, and more **memory-efficient** than using for-loops for building collections.
#
# ---
#
# ## 🔹 7.2 List Comprehension
#
# ```python
# [x * 2 for x in range(5)]
# # → [0, 2, 4, 6, 8]
# ```
#
# ✅ With condition/filter:
#
# ```python
# [x for x in range(10) if x % 2 == 0]
# # → [0, 2, 4, 6, 8]
# ```
#
# ---
#
# ## 🔹 7.3 Set Comprehension
#
# ```python
# {x**2 for x in range(5)}
# # → {0, 1, 4, 9, 16}
# ```
#
# ✅ Removes **duplicates** automatically due to set behavior.
#
# ---
#
# ## 🔹 7.4 Dict Comprehension
#
# ```python
# {k: v for k, v in [("a", 1), ("b", 2)]}
# # → {'a': 1, 'b': 2}
# ```
#
# ✅ Works well with:
#
# - `enumerate()`
# - `.items()` from dictionaries
#
# ---
#
# ## 🔹 7.5 Nested Comprehensions
#
# ```python
# [[i * j for j in range(3)] for i in range(2)]
# # → [[0, 0, 0], [0, 1, 2]]
# ```
#
# ✅ You can nest any kind of comprehension
# ❌ Readability decreases with complexity
#
# ---
#
# ## 🔹 7.6 Generator Expressions
#
# ### 🧠 Theory:
#
# Similar to list comprehensions but uses `()` instead of `[]`, and returns a **generator object** (lazy iterator).
#
# ```python
# gen = (x * 2 for x in range(5))
# next(gen)  # → 0
# next(gen)  # → 2
# ```
#
# ✅ **Memory-efficient**
# ❌ Cannot be indexed
# ✅ **One-time iterable**
#
# ---
#
# ## 🔹 7.7 When to Use Which?
#
# | Type        | Syntax              | Materializes in Memory? | Use Case                         |
# |-------------|---------------------|--------------------------|----------------------------------|
# | List Comp   | `[x for x in it]`   | ✅ Yes                   | Fast construction of new list    |
# | Set Comp    | `{x for x in it}`   | ✅ Yes                   | Deduplicated collection          |
# | Dict Comp   | `{k: v for ...}`    | ✅ Yes                   | Mapping keys to values           |
# | Generator   | `(x for x in it)`   | ❌ Lazy                  | Stream-like or large datasets    |
#
# ---
#
# ## ✅ Summary Table
#
# | Feature             | List Comp | Set Comp | Dict Comp | Generator |
# |---------------------|-----------|----------|-----------|-----------|
# | Uses brackets       | `[]`      | `{}`     | `{}`      | `()`      |
# | Stores in memory?   | ✅         | ✅        | ✅         | ❌         |
# | Can iterate         | ✅         | ✅        | ✅         | ✅ (once)  |
# | Supports filtering  | ✅         | ✅        | ✅         | ✅         |
# | Use case            | Small/medium lists | De-duplication | Key-value map | Lazy/stream data |

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

# (question, answer, PEMDAS-style mnemonic)
flashcards = [
# 7.1 What Is a Comprehension?
("What is a comprehension in Python?",
 "A compact syntax for generating new sequences from existing iterables.",
 "**Mnemonic:** Create Collections Cleanly"),

("Why use comprehensions?",
 "They’re faster, more concise, and more memory-efficient than equivalent for loops.",
 "**Mnemonic:** Comprehensions Run Faster"),

# 7.2 List Comprehensions
("What is the syntax of a list comprehension?",
 "`[expr for item in iterable]` — creates a list from an iterable.",
 "**Mnemonic:** Lists Form Easily"),

("How do you filter a list comprehension?",
 "Add an `if` condition at the end: `[x for x in seq if cond]`.",
 "**Mnemonic:** If Filters Cleanly"),

("What does `[x * 2 for x in range(5)]` return?",
 "`[0, 2, 4, 6, 8]` — applies the expression to each element.",
 "**Mnemonic:** Multiply Every Step"),

# 7.3 Set Comprehensions
("What is a set comprehension?",
 "`{expr for item in iterable}` — builds a set with unique values.",
 "**Mnemonic:** Sets Filter Uniques"),

("What’s special about set comprehensions?",
 "They automatically remove duplicates.",
 "**Mnemonic:** Duplicates Are Out"),

("What does `{x**2 for x in range(5)}` return?",
 "`{0, 1, 4, 9, 16}` — squares of numbers 0–4.",
 "**Mnemonic:** Squares Are Simple"),

# 7.4 Dict Comprehensions
("What is the syntax of a dict comprehension?",
 "`{k: v for (k, v) in iterable}` — builds a dictionary from key-value pairs.",
 "**Mnemonic:** Keys Value Every Loop"),

("How can you use `enumerate()` with a dict comp?",
 "```python\n{i: c for i, c in enumerate('abc')}\n``` → `{0: 'a', 1: 'b', 2: 'c'}`",
 "**Mnemonic:** Enumerate Becomes Dictionary"),

("What happens if keys repeat in a dict comp?",
 "Later keys overwrite earlier ones.",
 "**Mnemonic:** Keys Don’t Clone"),

# 7.5 Nested Comprehensions
("What is a nested comprehension?",
 "A comprehension inside another — often used for matrix-style structures.",
 "**Mnemonic:** Nesting Builds Boxes"),

("Example of a nested list comprehension?",
 "`[[i * j for j in range(3)] for i in range(2)]` → `[[0, 0, 0], [0, 1, 2]]`",
 "**Mnemonic:** Multiply Rows Columns"),

("Downside of nested comprehensions?",
 "They can be hard to read or debug.",
 "**Mnemonic:** Nested Logic Risks Clarity"),

# 7.6 Generator Expressions
("What is a generator expression?",
 "Like a list comprehension but uses `()` and returns a lazy iterator.",
 "**Mnemonic:** Generate On Demand"),

("What’s the syntax for a generator expression?",
 "`(x for x in iterable)` — parentheses instead of brackets.",
 "**Mnemonic:** Parentheses Produce Generators"),

("Can you index a generator?",
 "No — you must iterate or use `next()`.",
 "**Mnemonic:** No Index In Generators"),

("Can you reuse a generator?",
 "No — once exhausted, it cannot be reused.",
 "**Mnemonic:** One Ride Only"),

# 7.7 When to Use Which
("When should you use a list comprehension?",
 "When you need to build and store a new list in memory.",
 "**Mnemonic:** Lists Live In RAM"),

("When should you use a set comprehension?",
 "When you need a deduplicated collection.",
 "**Mnemonic:** Sets Save Uniques"),

("When should you use a dict comprehension?",
 "When building a key-value mapping from a sequence.",
 "**Mnemonic:** Dictionaries Construct Mappings"),

("When should you use a generator expression?",
 "When working with large or infinite data streams.",
 "**Mnemonic:** Generators Stream Smart"),

# 7.8 Summary Table
("What do all comprehensions support?",
 "Filtering with `if`, and iteration over any iterable.",
 "**Mnemonic:** If Iterates Always"),

("Do all comprehensions store results in memory?",
 "Only list, set, and dict comprehensions do — generator expressions do not.",
 "**Mnemonic:** Memory Matters Except Generator"),

("Which comprehension type is best for pipelines?",
 "Generator expressions — lazy and memory-efficient.",
 "**Mnemonic:** Pipes Prefer Generators"),

("Can comprehensions be nested?",
 "Yes — but deep nesting can hurt readability.",
 "**Mnemonic:** Nest With Caution")
]
index = 0
showing_answer = False
output = widgets.Output()

# Buttons
prev_button = widgets.Button(description="◀️ Previous")
show_button = widgets.Button(description="Show Answer 👁️")
next_button = widgets.Button(description="Next ▶️")
restart_button = widgets.Button(description="🔁 Restart")
restart_button.layout.display = 'none'  # Hidden initially

def update_card():
    with output:
        clear_output(wait=True)
        question, answer, mnemonic = flashcards[index]
        display(Markdown(f"**Q:** {question}"))
        if showing_answer:
            display(Markdown(f"\n---\n\n**A:** {answer}\n\n{mnemonic}"))

    # Update button states
    prev_button.disabled = index == 0
    next_button.disabled = False  # always enabled unless at end
    show_button.description = "Hide Answer 🙈" if showing_answer else "Show Answer 👁️"

def show_toggle(_):
    global showing_answer
    showing_answer = not showing_answer
    update_card()

def next_card(_):
    global index, showing_answer
    if index < len(flashcards) - 1:
        index += 1
        showing_answer = False
        update_card()
    else:
        with output:
            clear_output()
            display(Markdown("🎉 **You've reached the end of the flashcards.**"))
        show_button.layout.display = 'none'
        next_button.layout.display = 'none'
        prev_button.layout.display = 'none'
        restart_button.layout.display = ''

def prev_card(_):
    global index, showing_answer
    if index > 0:
        index -= 1
        showing_answer = False
        update_card()

def restart(_):
    global index, showing_answer
    index = 0
    showing_answer = False
    show_button.layout.display = ''
    next_button.layout.display = ''
    prev_button.layout.display = ''
    restart_button.layout.display = 'none'
    update_card()

# Attach handlers
show_button.on_click(show_toggle)
next_button.on_click(next_card)
prev_button.on_click(prev_card)
restart_button.on_click(restart)

# Initialize display
update_card()
display(widgets.HBox([prev_button, show_button, next_button, restart_button]), output)

# %% [markdown]
# # 🧠 Section 8: Iterators and Generators
#
# This section covers:
#
# - Iterables vs iterators
# - `iter()` and `next()`
# - Generator functions with `yield`
# - Generator expressions
# - Exhaustion and state retention
#
# ---
#
# ## 🔹 8.1 What Is an Iterable?
#
# ### 🧠 Theory:
#
# An **iterable** is any object that can be looped over with a `for` loop.
# It must implement the `__iter__()` method.
#
# ```python
# for x in [1, 2, 3]:  # list is iterable
#     print(x)
# ```
#
# ✅ Examples of iterables:
#
# - `list`, `tuple`, `str`, `set`, `dict`, `range()`, `file`
#
# ---
#
# ## 🔹 8.2 What Is an Iterator?
#
# ### 🧠 Theory:
#
# An **iterator** is an object that:
#
# - Implements `__iter__()` (returns self)
# - Implements `__next__()` (returns next value or raises `StopIteration`)
#
# ```python
# nums = iter([10, 20, 30])  # create an iterator
# print(next(nums))  # → 10
# print(next(nums))  # → 20
# ```
#
# ✅ You can manually advance any iterator with `next()`.
#
# ---
#
# ## 🔹 8.3 Generator Functions
#
# ### 🧠 Theory:
#
# A **generator function** uses `yield` instead of `return`.
# It produces values one at a time and **remembers state** between calls.
#
# ```python
# def count_up(n):
#     i = 0
#     while i <= n:
#         yield i
#         i += 1
#
# g = count_up(2)
# next(g)  # → 0
# next(g)  # → 1
# next(g)  # → 2
# ```
#
# ✅ Calling a generator function returns a **generator object**.
#
# ---
#
# ## 🔹 8.4 Generator Expressions
#
# ### 🧠 Theory:
#
# Like list comprehensions, but use `()` and return a generator (lazy sequence):
#
# ```python
# gen = (x * 2 for x in range(3))
# list(gen)  # → [0, 2, 4]
# ```
#
# ✅ Can be used with `sum()`, `any()`, `all()`, `max()`, etc.
# ❌ Cannot be indexed
# ❌ Can only be iterated **once**
#
# ---
#
# ## 🔹 8.5 Generator Exhaustion
#
# ```python
# g = (x for x in range(3))
# print(list(g))  # [0, 1, 2]
# print(list(g))  # [] ← already exhausted!
# ```
#
# ✅ Once a generator finishes, it **cannot be restarted or reused**.
#
# ---
#
# ## 🔹 8.6 Why Use Generators?
#
# | Benefit           | Explanation                                |
# |-------------------|--------------------------------------------|
# | Lazy evaluation   | Compute values only when needed            |
# | Memory efficient  | Doesn’t store the full sequence in memory  |
# | Maintains state   | Between `yield` calls                      |
# | Pipeline-friendly | Can be chained for multi-step processing   |
#
# ---
#
# ## ✅ Summary Table
#
# | Feature           | Generator Function      | Generator Expression     |
# |-------------------|--------------------------|---------------------------|
# | Syntax            | Uses `yield`             | Uses `( ... for ... )`    |
# | Returns           | Generator object         | Generator object          |
# | Reusable          | ❌ One-time only         | ❌ One-time only          |
# | Memory-efficient  | ✅                       | ✅                        |
# | Indexable         | ❌                       | ❌                        |
# | Iterable          | ✅                       | ✅                        |

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

# (question, answer, PEMDAS-style mnemonic)
flashcards = [
# 7.1 What Is a Comprehension?
# 8.1 What Is an Iterable?
("What is an iterable in Python?",
 "An object you can loop over; it implements `__iter__()`.",
 "**Mnemonic:** Iterables Enable Repeating"),

("Examples of iterables?",
 "`list`, `tuple`, `str`, `set`, `dict`, `range()`, `file`, etc.",
 "**Mnemonic:** Lists To Strings Read Dictionaries"),

("How does Python use iterables?",
 "`for` loops call `iter()` internally to create an iterator.",
 "**Mnemonic:** For Iterates Everything"),

# 8.2 What Is an Iterator?
("What is an iterator?",
 "An object that implements `__iter__()` (returns self) and `__next__()` (returns next item).",
 "**Mnemonic:** Iterator Returns Next"),

("How do you manually iterate?",
 "Use `next()` on an iterator object.\n```python\nx = iter([1, 2]); next(x)\n```",
 "**Mnemonic:** Next Every Time"),

("What happens when an iterator is exhausted?",
 "It raises `StopIteration`.",
 "**Mnemonic:** Stop Is The End"),

("How do you create an iterator from an iterable?",
 "Call `iter()` on the iterable.\n```python\niter([1, 2, 3])\n```",
 "**Mnemonic:** Iter On Iterable"),

# 8.3 Generator Functions
("What is a generator function?",
 "A function that uses `yield` to return values lazily.",
 "**Mnemonic:** Yield Every Lazy Data"),

("What happens when a generator function is called?",
 "It returns a generator object, not a result.",
 "**Mnemonic:** Generators Return Generators"),

("What’s the difference between `yield` and `return`?",
 "`yield` pauses the function and retains state; `return` ends it.",
 "**Mnemonic:** Yield Saves State"),

("Can a generator function maintain internal state?",
 "Yes — it resumes from where it left off after each `yield`.",
 "**Mnemonic:** Yield Means Memory"),

# 8.4 Generator Expressions
("What is a generator expression?",
 "A compact generator defined with parentheses: `(x for x in iterable)`.",
 "**Mnemonic:** Parentheses Generate Lazily"),

("How does it differ from a list comprehension?",
 "It uses `()` and returns a generator instead of a list.",
 "**Mnemonic:** Lists Materialize, Generators Stream"),

("Can you reuse a generator expression?",
 "No — it is one-time and becomes exhausted after use.",
 "**Mnemonic:** One Loop Only"),

("Can you index a generator expression?",
 "No — generators can only be iterated, not indexed.",
 "**Mnemonic:** Indexing Not Allowed"),

# 8.5 Generator Exhaustion
("What happens after a generator is exhausted?",
 "Further iteration returns nothing; the generator is finished.",
 "**Mnemonic:** Gone After Run"),

("Can you restart a generator?",
 "No — create a new one instead.",
 "**Mnemonic:** New Generator Needed"),

# 8.6 Why Use Generators?
("Why use generators instead of lists?",
 "They are memory-efficient and allow lazy evaluation.",
 "**Mnemonic:** Generate On Demand"),

("What makes generators pipeline-friendly?",
 "You can chain them to process data step by step.",
 "**Mnemonic:** Pipe Through Yields"),

("What are the benefits of generator functions?",
 "Lazy computation, memory efficiency, state retention.",
 "**Mnemonic:** Lazy Efficient Stateful"),

# 8.7 Summary Table
("What do generator functions and expressions return?",
 "Both return generator objects (iterators).",
 "**Mnemonic:** Functions Or Parentheses = Generator"),

("Are generator functions reusable?",
 "No — they run once and are exhausted.",
 "**Mnemonic:** Run Once Only"),

("Do generator expressions support filtering?",
 "Yes — like comprehensions, they support `if` clauses.",
 "**Mnemonic:** If Works With Generators"),

("Are generators iterable?",
 "Yes — generator objects are iterable.",
 "**Mnemonic:** Generator Equals Iterable")
]
index = 0
showing_answer = False
output = widgets.Output()

# Buttons
prev_button = widgets.Button(description="◀️ Previous")
show_button = widgets.Button(description="Show Answer 👁️")
next_button = widgets.Button(description="Next ▶️")
restart_button = widgets.Button(description="🔁 Restart")
restart_button.layout.display = 'none'  # Hidden initially

def update_card():
    with output:
        clear_output(wait=True)
        question, answer, mnemonic = flashcards[index]
        display(Markdown(f"**Q:** {question}"))
        if showing_answer:
            display(Markdown(f"\n---\n\n**A:** {answer}\n\n{mnemonic}"))

    # Update button states
    prev_button.disabled = index == 0
    next_button.disabled = False  # always enabled unless at end
    show_button.description = "Hide Answer 🙈" if showing_answer else "Show Answer 👁️"

def show_toggle(_):
    global showing_answer
    showing_answer = not showing_answer
    update_card()

def next_card(_):
    global index, showing_answer
    if index < len(flashcards) - 1:
        index += 1
        showing_answer = False
        update_card()
    else:
        with output:
            clear_output()
            display(Markdown("🎉 **You've reached the end of the flashcards.**"))
        show_button.layout.display = 'none'
        next_button.layout.display = 'none'
        prev_button.layout.display = 'none'
        restart_button.layout.display = ''

def prev_card(_):
    global index, showing_answer
    if index > 0:
        index -= 1
        showing_answer = False
        update_card()

def restart(_):
    global index, showing_answer
    index = 0
    showing_answer = False
    show_button.layout.display = ''
    next_button.layout.display = ''
    prev_button.layout.display = ''
    restart_button.layout.display = 'none'
    update_card()

# Attach handlers
show_button.on_click(show_toggle)
next_button.on_click(next_card)
prev_button.on_click(prev_card)
restart_button.on_click(restart)

# Initialize display
update_card()
display(widgets.HBox([prev_button, show_button, next_button, restart_button]), output)

# %% [markdown]
# # 🧠 Section 9: Advanced Functions (with Proper Theory + Comments)
#
# Includes:
#
# - Precise theory for each concept
# - One example per topic with comments
# - No repetition or bloating
#
# ---
#
# ## 🔹 9.1 `*args` and `**kwargs`
#
# ### 🧠 Theory:
#
# Used when you don't know how many arguments will be passed.
#
# - `*args` captures extra **positional arguments** as a `tuple`
# - `**kwargs` captures extra **keyword arguments** as a `dict`
#
# ```python
# def demo(*args, **kwargs):
#     print("args:", args)      # tuple: (1, 2)
#     print("kwargs:", kwargs)  # dict: {'a': 3, 'b': 4}
#
# demo(1, 2, a=3, b=4)
# ```
#
# ---
#
# ## 🔹 9.2 Positional-Only and Keyword-Only Parameters
#
# ### 🧠 Theory:
#
# Python allows you to explicitly control **how** arguments must be passed:
#
# - `/` → everything **before** it is positional-only
# - `*` → everything **after** it is keyword-only
#
# ```python
# def f(a, /, b, *, c):     # a is positional-only, c is keyword-only
#     print(a, b, c)
#
# f(1, b=2, c=3)             # ✅ valid
# # f(a=1, b=2, c=3)         # ❌ Error: a can't be passed by keyword
# ```
#
# ---
#
# ## 🔹 9.3 Lambdas
#
# ### 🧠 Theory:
#
# A `lambda` is a **single-expression anonymous function**.
# Best for short logic in sorting, filtering, or mapping.
#
# ```python
# square = lambda x: x * x
# print(square(3))  # → 9
# ```
#
# Equivalent to:
#
# ```python
# def square(x):
#     return x * x
# ```
#
# ---
#
# ## 🔹 9.4 Closures and `nonlocal`
#
# ### 🧠 Theory:
#
# A **closure** is an inner function that remembers variables from its enclosing scope.
#
# ```python
# def outer(x):
#     def inner(y):
#         return x + y  # x is retained
#     return inner
#
# f = outer(10)
# print(f(5))  # → 15
# ```
#
# ### 🔸 `nonlocal`: Allows modifying an enclosing (non-global) variable
#
# ```python
# def outer():
#     x = 1
#     def inner():
#         nonlocal x
#         x += 1
#         return x
#     return inner()
#
# print(outer())  # → 2
# ```
#
# ---
#
# ## 🔹 9.5 Decorators (Basic)
#
# ### 🧠 Theory:
#
# A **decorator** is a higher-order function that:
#
# - Accepts another function
# - Returns a modified version of that function
#
# Use cases:
#
# - Logging
# - Access control
# - Timing
# - Validation
#
# ```python
# def decorator(func):
#     def wrapper(*args, **kwargs):
#         print("Before")
#         result = func(*args, **kwargs)
#         print("After")
#         return result
#     return wrapper
#
# @decorator
# def greet(name):
#     print("Hello", name)
#
# greet("Alice")
# ```
#
# ---
#
# ## 🔹 9.6 Stacked Decorators
#
# ### 🧠 Theory:
#
# Multiple decorators can be stacked.
# The **closest to the function runs first**.
#
# ```python
# def deco1(func):
#     def wrapper(*args, **kwargs):
#         print("deco1 start")
#         result = func(*args, **kwargs)
#         print("deco1 end")
#         return result
#     return wrapper
#
# def deco2(func):
#     def wrapper(*args, **kwargs):
#         print("deco2 start")
#         result = func(*args, **kwargs)
#         print("deco2 end")
#         return result
#     return wrapper
#
# @deco1
# @deco2
# def task():
#     print("doing task")
#
# task()
# # Output:
# # deco1 start
# # deco2 start
# # doing task
# # deco2 end
# # deco1 end
# ```
#
# ---
#
# ## 🔹 9.7 Decorators With Arguments
#
# ### 🧠 Theory:
#
# To pass parameters to a decorator, use a **decorator factory** — a function that returns a decorator.
#
# ```python
# def repeat(n):
#     def decorator(func):
#         def wrapper(*args, **kwargs):
#             for _ in range(n):
#                 func(*args, **kwargs)
#         return wrapper
#     return decorator
#
# @repeat(3)
# def greet():
#     print("Hi")
#
# greet()  # Hi (printed 3 times)
# ```
#
# ---
#
# ## 🔹 9.8 Built-in Decorators
#
# ### 🧠 Theory:
#
# Python includes built-in decorators for **methods and properties**.
#
# #### ✅ `@staticmethod`: No `self`, acts like a plain function
#
# ```python
# class Tool:
#     @staticmethod
#     def ping():
#         print("pong")
#
# Tool.ping()
# ```
#
# ---
#
# #### ✅ `@classmethod`: Receives the class (`cls`) as the first argument
#
# ```python
# class Tool:
#     version = 1
#
#     @classmethod
#     def get_version(cls):
#         return cls.version
# ```
#
# ---
#
# #### ✅ `@property`: Makes a method act like a **read-only attribute**
#
# ```python
# class Temp:
#     def __init__(self, c):
#         self._celsius = c
#
#     @property
#     def fahrenheit(self):
#         return self._celsius * 9 / 5 + 32
#
# t = Temp(0)
# print(t.fahrenheit)  # → 32.0
# ```
#
# ---
#
# ## ✅ Section 9 Summary
#
# | Feature                  | Theory Summary                                       |
# |--------------------------|------------------------------------------------------|
# | `*args`, `**kwargs`      | Accept variable-length argument sets                 |
# | Positional/Keyword params| Enforce argument style using `/` and `*`             |
# | `lambda`                 | Single-expression anonymous function                 |
# | Closure                  | Inner function remembers outer scope variables       |
# | `nonlocal`               | Modifies a variable from an enclosing scope          |
# | Decorator                | Function wrapper for added behavior                  |
# | Stacked Decorators       | Multiple decorators apply behavior in layers         |
# | Decorator w/ args        | Factory function returns a custom decorator          |
# | Built-in Decorators      | Class tools: staticmethod, classmethod, property     |

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

# (question, answer, PEMDAS-style mnemonic)
flashcards = [
# 9.1 *args and **kwargs
("What does *args do?",
 "Captures extra positional arguments as a tuple.",
 "**Mnemonic:** Args Receive Grouped Stuff"),

("What does **kwargs do?",
 "Captures extra keyword arguments as a dictionary.",
 "**Mnemonic:** Kwargs Wrap Named Stuff"),

("Can you mix *args and **kwargs?",
 "Yes — `*args` must come before `**kwargs`.",
 "**Mnemonic:** Stars Then Double Stars"),

# 9.2 Positional-Only and Keyword-Only Parameters
("What does `/` mean in a function signature?",
 "Marks all parameters before it as positional-only.",
 "**Mnemonic:** Slash Stops Keywords"),

("What does `*` mean in a function signature?",
 "Marks all parameters after it as keyword-only.",
 "**Mnemonic:** Star Starts Keywords"),

("Example of positional-only and keyword-only?",
 "`def f(a, /, b, *, c): ...` — `a` must be positional, `c` must be keyword.",
 "**Mnemonic:** Before Slash Positional, After Star Keyword"),

# 9.3 Lambda Functions
("What is a lambda function?",
 "A short anonymous function written as `lambda x: expr`.",
 "**Mnemonic:** Light Anonymous Method"),

("When should you use lambda?",
 "For quick functions like in `map()`, `sorted()`, etc.",
 "**Mnemonic:** Lambda Is For Throwaways"),

# 9.4 Closures and nonlocal
("What is a closure?",
 "An inner function that remembers variables from its enclosing scope.",
 "**Mnemonic:** Closure Remembers Context"),

("How does `nonlocal` work?",
 "It modifies a variable from the nearest enclosing (non-global) scope.",
 "**Mnemonic:** Nonlocal Reaches Up"),

("Why are closures useful?",
 "They preserve state across multiple function calls.",
 "**Mnemonic:** Closure Keeps State"),

# 9.5 Decorators
("What is a decorator?",
 "A function that takes another function and returns a modified one.",
 "**Mnemonic:** Decorate With Functions"),

("Why use decorators?",
 "To add behavior like logging, timing, access control.",
 "**Mnemonic:** Add Behavior Without Change"),

("What does `@decorator` mean?",
 "It applies the decorator function to the decorated function.",
 "**Mnemonic:** At Symbol Applies"),

# 9.6 Stacked Decorators
("What is a stacked decorator?",
 "Multiple decorators applied in order. Bottom one runs first.",
 "**Mnemonic:** Stack Runs Bottom-Up"),

("What is the output order for stacked decorators?",
 "`deco1` wraps `deco2`, so output is: deco1 > deco2 > function > deco2 > deco1",
 "**Mnemonic:** Outer Wraps Inner"),

# 9.7 Decorators with Arguments
("How do you pass arguments to a decorator?",
 "Use a function that returns a decorator.",
 "**Mnemonic:** Decorator Factory Pattern"),

("What’s the structure of a parametric decorator?",
 "`outer(arg) → decorator(func) → wrapper(*args, **kwargs)`",
 "**Mnemonic:** Three Layers Deep"),

# 9.8 Built-in Decorators
("What does @staticmethod do?",
 "Defines a method without access to `self` or `cls`.",
 "**Mnemonic:** Static Stays Solo"),

("What does @classmethod do?",
 "Receives the class (`cls`) as the first argument.",
 "**Mnemonic:** Class Comes First"),

("What does @property do?",
 "Turns a method into a read-only attribute.",
 "**Mnemonic:** Property Looks Like Field"),

("Can @property be combined with setter?",
 "Yes — use `@property` and `@name.setter` for mutability.",
 "**Mnemonic:** Property Gets Settable"),

# 9.9 Summary
("What does `*args` and `**kwargs` allow?",
 "Flexible argument passing for unknown or variable inputs.",
 "**Mnemonic:** Star Means Flexibility"),

("What is the purpose of `lambda`?",
 "Concise anonymous functions for short-term logic.",
 "**Mnemonic:** Short Function No Name"),

("What’s the benefit of closures?",
 "Remember state from outer scopes even after they return.",
 "**Mnemonic:** Scope Persistence"),

("When are decorators useful?",
 "When you want to add reusable behavior around functions.",
 "**Mnemonic:** Wrap With Power"),

("What's the structure of a stacked decorator?",
 "`@outer` wraps `@inner`, which wraps the function.",
 "**Mnemonic:** Wrap In Reverse Order")
]
index = 0
showing_answer = False
output = widgets.Output()

# Buttons
prev_button = widgets.Button(description="◀️ Previous")
show_button = widgets.Button(description="Show Answer 👁️")
next_button = widgets.Button(description="Next ▶️")
restart_button = widgets.Button(description="🔁 Restart")
restart_button.layout.display = 'none'  # Hidden initially

def update_card():
    with output:
        clear_output(wait=True)
        question, answer, mnemonic = flashcards[index]
        display(Markdown(f"**Q:** {question}"))
        if showing_answer:
            display(Markdown(f"\n---\n\n**A:** {answer}\n\n{mnemonic}"))

    # Update button states
    prev_button.disabled = index == 0
    next_button.disabled = False  # always enabled unless at end
    show_button.description = "Hide Answer 🙈" if showing_answer else "Show Answer 👁️"

def show_toggle(_):
    global showing_answer
    showing_answer = not showing_answer
    update_card()

def next_card(_):
    global index, showing_answer
    if index < len(flashcards) - 1:
        index += 1
        showing_answer = False
        update_card()
    else:
        with output:
            clear_output()
            display(Markdown("🎉 **You've reached the end of the flashcards.**"))
        show_button.layout.display = 'none'
        next_button.layout.display = 'none'
        prev_button.layout.display = 'none'
        restart_button.layout.display = ''

def prev_card(_):
    global index, showing_answer
    if index > 0:
        index -= 1
        showing_answer = False
        update_card()

def restart(_):
    global index, showing_answer
    index = 0
    showing_answer = False
    show_button.layout.display = ''
    next_button.layout.display = ''
    prev_button.layout.display = ''
    restart_button.layout.display = 'none'
    update_card()

# Attach handlers
show_button.on_click(show_toggle)
next_button.on_click(next_card)
prev_button.on_click(prev_card)
restart_button.on_click(restart)

# Initialize display
update_card()
display(widgets.HBox([prev_button, show_button, next_button, restart_button]), output)
